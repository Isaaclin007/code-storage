# 2018-12-24  146.202972
# 2018-12-26  156.498810
# 2018-12-27  155.483154
# 2018-12-28  155.562820
# 2018-12-31  157.066376
# 2019-01-02  157.245605
#
# [7308 rows x 6 columns]

# %%
df.to_csv('1.csv')

# %%
# df_ohlc = df['Adj Close'].resample('5D').ohlc()
# df_volume = df['Volume'].resample('5D').sum()

dic={}
dic['open']=df['Open']
dic['high']=df['High']
dic['low']=df['Low']
dic['close']=df['Close']
df_ohlc = pd.DataFrame(dic)

# %%
df_ohlc.head()
# Out:
#                  open       high        low      close
# Date
# 2016-05-02  17.180000  17.490000  17.180000  17.469999
# 2016-05-03  17.200001  17.510000  17.200001  17.450001
# 2016-05-04  17.400000  17.450001  17.180000  17.299999
# 2016-05-05  17.299999  17.389999  17.299999  17.350000
# 2016-05-06  17.299999  17.500000  17.200001  17.500000

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1),(5,0), rowspan=5, colspan=1, sharex=ax1)

# %%
df_ohlc.reset_index(inplace=True)

# %%
df_ohlc.head()
# Out:
#         Date       open       high        low      close
# 0 2016-05-02  17.180000  17.490000  17.180000  17.469999
# 1 2016-05-03  17.200001  17.510000  17.200001  17.450001
# 2 2016-05-04  17.400000  17.450001  17.180000  17.299999
# 3 2016-05-05  17.299999  17.389999  17.299999  17.350000
# 4 2016-05-06  17.299999  17.500000  17.200001  17.500000

# %%
df_ohlc['Date'] = df_ohlc['Date'].map(mdates.date2num)

# %%
df_ohlc.head()
# Out:
#        Date       open       high        low      close
# 0  736086.0  17.180000  17.490000  17.180000  17.469999
# 1  736087.0  17.200001  17.510000  17.200001  17.450001
# 2  736088.0  17.400000  17.450001  17.180000  17.299999
# 3  736089.0  17.299999  17.389999  17.299999  17.350000
# 4  736090.0  17.299999  17.500000  17.200001  17.500000

# %%
ax1.xaxis_date()

# %%
candlestick_ohlc(ax1, df_ohlc.values, width=0.5, colorup='r', colordown='g')
# Out:
# ([<matplotlib.lines.Line2D at 0x1319b4748>,
#   <matplotlib.lines.Line2D at 0x13199a710>,
#   <matplotlib.lines.Line2D at 0x1319d0748>,
#   <matplotlib.lines.Line2D at 0x1319d0d68>,
#   <matplotlib.lines.Line2D at 0x1319d6438>,
#   <matplotlib.lines.Line2D at 0x1319d6ac8>,
#   <matplotlib.lines.Line2D at 0x1319d6f98>,
#   <matplotlib.lines.Line2D at 0x1319dd828>,
#   <matplotlib.lines.Line2D at 0x1319ddeb8>,
#   <matplotlib.lines.Line2D at 0x1319e6588>,
#   <matplotlib.lines.Line2D at 0x1319e6c18>,
#   <matplotlib.lines.Line2D at 0x1319f02e8>,
#   <matplotlib.lines.Line2D at 0x1319f0978>,
#   <matplotlib.lines.Line2D at 0x1319f0fd0>,
#   <matplotlib.lines.Line2D at 0x1319fa6d8>,
#   <matplotlib.lines.Line2D at 0x1319fad68>,
#   <matplotlib.lines.Line2D at 0x131a03438>,
#   <matplotlib.lines.Line2D at 0x131a03ac8>,
#   <matplotlib.lines.Line2D at 0x131a03f98>,
#   <matplotlib.lines.Line2D at 0x131a0f828>,
#   <matplotlib.lines.Line2D at 0x131a0feb8>,
#   <matplotlib.lines.Line2D at 0x131a18588>,
#   <matplotlib.lines.Line2D at 0x131a18c18>,
#   <matplotlib.lines.Line2D at 0x131a212e8>,
#   <matplotlib.lines.Line2D at 0x131a21978>,
#   <matplotlib.lines.Line2D at 0x131a21fd0>,
#   <matplotlib.lines.Line2D at 0x131a296d8>,
#   <matplotlib.lines.Line2D at 0x131a29d68>,
#   <matplotlib.lines.Line2D at 0x131a34438>,
#   <matplotlib.lines.Line2D at 0x131a34ac8>,
#   <matplotlib.lines.Line2D at 0x131a34f98>,
#   <matplotlib.lines.Line2D at 0x131a3d828>,
#   <matplotlib.lines.Line2D at 0x131a3deb8>,
#   <matplotlib.lines.Line2D at 0x131a46588>,
#   <matplotlib.lines.Line2D at 0x131a46c18>,
#   <matplotlib.lines.Line2D at 0x131a502e8>,
#   <matplotlib.lines.Line2D at 0x131a50978>,
#   <matplotlib.lines.Line2D at 0x131a50fd0>,
#   <matplotlib.lines.Line2D at 0x1319b4240>,
#   <matplotlib.lines.Line2D at 0x131a5ac18>,
#   <matplotlib.lines.Line2D at 0x131a662e8>,
#   <matplotlib.lines.Line2D at 0x131a66978>,
#   <matplotlib.lines.Line2D at 0x131a66fd0>,
#   <matplotlib.lines.Line2D at 0x131a706d8>,
#   <matplotlib.lines.Line2D at 0x131a70d68>,
#   <matplotlib.lines.Line2D at 0x131a7a438>,
#   <matplotlib.lines.Line2D at 0x131a7aac8>,
#   <matplotlib.lines.Line2D at 0x131a7af98>,
#   <matplotlib.lines.Line2D at 0x131a82828>,
#   <matplotlib.lines.Line2D at 0x131a82eb8>,
#   <matplotlib.lines.Line2D at 0x131a8b588>,
#   <matplotlib.lines.Line2D at 0x131a8bc18>,
#   <matplotlib.lines.Line2D at 0x131a942e8>,
#   <matplotlib.lines.Line2D at 0x131a94978>,
#   <matplotlib.lines.Line2D at 0x131a94fd0>,
#   <matplotlib.lines.Line2D at 0x131a9f6d8>,
#   <matplotlib.lines.Line2D at 0x131a9fd68>,
#   <matplotlib.lines.Line2D at 0x131aa7438>,
#   <matplotlib.lines.Line2D at 0x131aa7ac8>,
#   <matplotlib.lines.Line2D at 0x131aa7f98>,
#   <matplotlib.lines.Line2D at 0x131ab5828>,
#   <matplotlib.lines.Line2D at 0x131ab5eb8>,
#   <matplotlib.lines.Line2D at 0x131abe588>,
#   <matplotlib.lines.Line2D at 0x131abec18>,
#   <matplotlib.lines.Line2D at 0x131ac62e8>,
#   <matplotlib.lines.Line2D at 0x131ac6978>,
#   <matplotlib.lines.Line2D at 0x131ac6fd0>,
#   <matplotlib.lines.Line2D at 0x131ad06d8>,
#   <matplotlib.lines.Line2D at 0x131ad0d68>,
#   <matplotlib.lines.Line2D at 0x131ad9438>,
#   <matplotlib.lines.Line2D at 0x131ad9ac8>,
#   <matplotlib.lines.Line2D at 0x131ad9f98>,
#   <matplotlib.lines.Line2D at 0x131cb1828>,
#   <matplotlib.lines.Line2D at 0x131cb1eb8>,
#   <matplotlib.lines.Line2D at 0x131cbb588>,
#   <matplotlib.lines.Line2D at 0x131cbbc18>,
#   <matplotlib.lines.Line2D at 0x131cc72e8>,
#   <matplotlib.lines.Line2D at 0x131cc7978>,
#   <matplotlib.lines.Line2D at 0x131cc7fd0>,
#   <matplotlib.lines.Line2D at 0x131ccf6d8>,
#   <matplotlib.lines.Line2D at 0x131ccfd68>,
#   <matplotlib.lines.Line2D at 0x131cdb438>,
#   <matplotlib.lines.Line2D at 0x131cdbac8>,
#   <matplotlib.lines.Line2D at 0x131cdbf98>,
#   <matplotlib.lines.Line2D at 0x131ce4828>,
#   <matplotlib.lines.Line2D at 0x131ce4eb8>,
#   <matplotlib.lines.Line2D at 0x132503588>,
#   <matplotlib.lines.Line2D at 0x132503c18>,
#   <matplotlib.lines.Line2D at 0x13250b2e8>,
#   <matplotlib.lines.Line2D at 0x13250b978>,
#   <matplotlib.lines.Line2D at 0x13250bfd0>,
#   <matplotlib.lines.Line2D at 0x1325166d8>,
#   <matplotlib.lines.Line2D at 0x132516d68>,
#   <matplotlib.lines.Line2D at 0x13251e438>,
#   <matplotlib.lines.Line2D at 0x13251eac8>,
#   <matplotlib.lines.Line2D at 0x13251ef98>,
#   <matplotlib.lines.Line2D at 0x132528828>,
#   <matplotlib.lines.Line2D at 0x132528eb8>,
#   <matplotlib.lines.Line2D at 0x132532588>,
#   <matplotlib.lines.Line2D at 0x132532c18>,
#   <matplotlib.lines.Line2D at 0x13253c2e8>,
#   <matplotlib.lines.Line2D at 0x13253c940>,
#   <matplotlib.lines.Line2D at 0x13253cf98>,
#   <matplotlib.lines.Line2D at 0x132546630>,
#   <matplotlib.lines.Line2D at 0x132546c88>,
#   <matplotlib.lines.Line2D at 0x132550320>,
#   <matplotlib.lines.Line2D at 0x132550978>,
#   <matplotlib.lines.Line2D at 0x132550fd0>,
#   <matplotlib.lines.Line2D at 0x13255b668>,
#   <matplotlib.lines.Line2D at 0x13255bcc0>,
#   <matplotlib.lines.Line2D at 0x132563358>,
#   <matplotlib.lines.Line2D at 0x1325639b0>,
#   <matplotlib.lines.Line2D at 0x132563fd0>,
#   <matplotlib.lines.Line2D at 0x13256f6a0>,
#   <matplotlib.lines.Line2D at 0x13256fcf8>,
#   <matplotlib.lines.Line2D at 0x132576390>,
#   <matplotlib.lines.Line2D at 0x1325769e8>,
#   <matplotlib.lines.Line2D at 0x132576eb8>,
#   <matplotlib.lines.Line2D at 0x1325816d8>,
#   <matplotlib.lines.Line2D at 0x132581d30>,
#   <matplotlib.lines.Line2D at 0x13258d3c8>,
#   <matplotlib.lines.Line2D at 0x13258da20>,
#   <matplotlib.lines.Line2D at 0x13258def0>,
#   <matplotlib.lines.Line2D at 0x132597710>,
#   <matplotlib.lines.Line2D at 0x132597d68>,
#   <matplotlib.lines.Line2D at 0x13259f400>,
#   <matplotlib.lines.Line2D at 0x13259fa58>,
#   <matplotlib.lines.Line2D at 0x13259ff28>,
#   <matplotlib.lines.Line2D at 0x1325ab748>,
#   <matplotlib.lines.Line2D at 0x1325abda0>,
#   <matplotlib.lines.Line2D at 0x1325b5438>,
#   <matplotlib.lines.Line2D at 0x1325b5a90>,
#   <matplotlib.lines.Line2D at 0x1325b5f60>,
#   <matplotlib.lines.Line2D at 0x13329c780>,
#   <matplotlib.lines.Line2D at 0x13329cdd8>,
#   <matplotlib.lines.Line2D at 0x1332a5470>,
#   <matplotlib.lines.Line2D at 0x1332a5ac8>,
#   <matplotlib.lines.Line2D at 0x1332a5f98>,
#   <matplotlib.lines.Line2D at 0x1332ad7b8>,
#   <matplotlib.lines.Line2D at 0x1332ade10>,
#   <matplotlib.lines.Line2D at 0x1332b94a8>,
#   <matplotlib.lines.Line2D at 0x1332b9b00>,
#   <matplotlib.lines.Line2D at 0x1332b9fd0>,
#   <matplotlib.lines.Line2D at 0x1332c27f0>,
#   <matplotlib.lines.Line2D at 0x1332c2e48>,
#   <matplotlib.lines.Line2D at 0x1332ce4e0>,
#   <matplotlib.lines.Line2D at 0x1332ceb38>,
#   <matplotlib.lines.Line2D at 0x1332cefd0>,
#   <matplotlib.lines.Line2D at 0x1332d8828>,
#   <matplotlib.lines.Line2D at 0x1332d8e80>,
#   <matplotlib.lines.Line2D at 0x1332e2518>,
#   <matplotlib.lines.Line2D at 0x1332e2b70>,
#   <matplotlib.lines.Line2D at 0x1332eb208>,
#   <matplotlib.lines.Line2D at 0x1332eb860>,
#   <matplotlib.lines.Line2D at 0x1332ebeb8>,
#   <matplotlib.lines.Line2D at 0x1332f4550>,
#   <matplotlib.lines.Line2D at 0x1332f4ba8>,
#   <matplotlib.lines.Line2D at 0x1332fd240>,
#   <matplotlib.lines.Line2D at 0x1332fd898>,
#   <matplotlib.lines.Line2D at 0x1332fdef0>,
#   <matplotlib.lines.Line2D at 0x133308588>,
#   <matplotlib.lines.Line2D at 0x133308be0>,
#   <matplotlib.lines.Line2D at 0x133314278>,
#   <matplotlib.lines.Line2D at 0x1333148d0>,
#   <matplotlib.lines.Line2D at 0x133314f28>,
#   <matplotlib.lines.Line2D at 0x13331d5c0>,
#   <matplotlib.lines.Line2D at 0x13331dc18>,
#   <matplotlib.lines.Line2D at 0x1333282b0>,
#   <matplotlib.lines.Line2D at 0x133328908>,
#   <matplotlib.lines.Line2D at 0x133328f60>],
#  [<matplotlib.patches.Rectangle at 0x1319b4860>,
#   <matplotlib.patches.Rectangle at 0x1319d0128>,
#   <matplotlib.patches.Rectangle at 0x1319d0908>,
#   <matplotlib.patches.Rectangle at 0x1319d0f28>,
#   <matplotlib.patches.Rectangle at 0x1319d65f8>,
#   <matplotlib.patches.Rectangle at 0x1319d6c88>,
#   <matplotlib.patches.Rectangle at 0x1319dd358>,
#   <matplotlib.patches.Rectangle at 0x1319dd9e8>,
#   <matplotlib.patches.Rectangle at 0x1319e60b8>,
#   <matplotlib.patches.Rectangle at 0x1319e6748>,
#   <matplotlib.patches.Rectangle at 0x1319e6dd8>,
#   <matplotlib.patches.Rectangle at 0x1319f04a8>,
#   <matplotlib.patches.Rectangle at 0x1319f0b38>,
#   <matplotlib.patches.Rectangle at 0x1319fa208>,
#   <matplotlib.patches.Rectangle at 0x1319fa898>,
#   <matplotlib.patches.Rectangle at 0x1319faf28>,
#   <matplotlib.patches.Rectangle at 0x131a035f8>,
#   <matplotlib.patches.Rectangle at 0x131a03c88>,
#   <matplotlib.patches.Rectangle at 0x131a0f358>,
#   <matplotlib.patches.Rectangle at 0x131a0f9e8>,
#   <matplotlib.patches.Rectangle at 0x131a180b8>,
#   <matplotlib.patches.Rectangle at 0x131a18748>,
#   <matplotlib.patches.Rectangle at 0x131a18dd8>,
#   <matplotlib.patches.Rectangle at 0x131a214a8>,
#   <matplotlib.patches.Rectangle at 0x131a21b38>,
#   <matplotlib.patches.Rectangle at 0x131a29208>,
#   <matplotlib.patches.Rectangle at 0x131a29898>,
#   <matplotlib.patches.Rectangle at 0x131a29f28>,
#   <matplotlib.patches.Rectangle at 0x131a345f8>,
#   <matplotlib.patches.Rectangle at 0x131a34c88>,
#   <matplotlib.patches.Rectangle at 0x131a3d358>,
#   <matplotlib.patches.Rectangle at 0x131a3d9e8>,
#   <matplotlib.patches.Rectangle at 0x131a460b8>,
#   <matplotlib.patches.Rectangle at 0x131a46748>,
#   <matplotlib.patches.Rectangle at 0x131a46dd8>,
#   <matplotlib.patches.Rectangle at 0x131a504a8>,
#   <matplotlib.patches.Rectangle at 0x131a50b38>,
#   <matplotlib.patches.Rectangle at 0x131a5a208>,
#   <matplotlib.patches.Rectangle at 0x131a5a6d8>,
#   <matplotlib.patches.Rectangle at 0x131a5add8>,
#   <matplotlib.patches.Rectangle at 0x131a664a8>,
#   <matplotlib.patches.Rectangle at 0x131a66b38>,
#   <matplotlib.patches.Rectangle at 0x131a70208>,
#   <matplotlib.patches.Rectangle at 0x131a70898>,
#   <matplotlib.patches.Rectangle at 0x131a70f28>,
#   <matplotlib.patches.Rectangle at 0x131a7a5f8>,
#   <matplotlib.patches.Rectangle at 0x131a7ac88>,
#   <matplotlib.patches.Rectangle at 0x131a82358>,
#   <matplotlib.patches.Rectangle at 0x131a829e8>,
#   <matplotlib.patches.Rectangle at 0x131a8b0b8>,
#   <matplotlib.patches.Rectangle at 0x131a8b748>,
#   <matplotlib.patches.Rectangle at 0x131a8bdd8>,
#   <matplotlib.patches.Rectangle at 0x131a944a8>,
#   <matplotlib.patches.Rectangle at 0x131a94b38>,
#   <matplotlib.patches.Rectangle at 0x131a9f208>,
#   <matplotlib.patches.Rectangle at 0x131a9f898>,
#   <matplotlib.patches.Rectangle at 0x131a9ff28>,
#   <matplotlib.patches.Rectangle at 0x131aa75f8>,
#   <matplotlib.patches.Rectangle at 0x131aa7c88>,
#   <matplotlib.patches.Rectangle at 0x131ab5358>,
#   <matplotlib.patches.Rectangle at 0x131ab59e8>,
#   <matplotlib.patches.Rectangle at 0x131abe0b8>,
#   <matplotlib.patches.Rectangle at 0x131abe748>,
#   <matplotlib.patches.Rectangle at 0x131abedd8>,
#   <matplotlib.patches.Rectangle at 0x131ac64a8>,
#   <matplotlib.patches.Rectangle at 0x131ac6b38>,
#   <matplotlib.patches.Rectangle at 0x131ad0208>,
#   <matplotlib.patches.Rectangle at 0x131ad0898>,
#   <matplotlib.patches.Rectangle at 0x131ad0f28>,
#   <matplotlib.patches.Rectangle at 0x131ad95f8>,
#   <matplotlib.patches.Rectangle at 0x131ad9c88>,
#   <matplotlib.patches.Rectangle at 0x131cb1358>,
#   <matplotlib.patches.Rectangle at 0x131cb19e8>,
#   <matplotlib.patches.Rectangle at 0x131cbb0b8>,
#   <matplotlib.patches.Rectangle at 0x131cbb748>,
#   <matplotlib.patches.Rectangle at 0x131cbbdd8>,
#   <matplotlib.patches.Rectangle at 0x131cc74a8>,
#   <matplotlib.patches.Rectangle at 0x131cc7b38>,
#   <matplotlib.patches.Rectangle at 0x131ccf208>,
#   <matplotlib.patches.Rectangle at 0x131ccf898>,
#   <matplotlib.patches.Rectangle at 0x131ccff28>,
#   <matplotlib.patches.Rectangle at 0x131cdb5f8>,
#   <matplotlib.patches.Rectangle at 0x131cdbc88>,
#   <matplotlib.patches.Rectangle at 0x131ce4358>,
#   <matplotlib.patches.Rectangle at 0x131ce49e8>,
#   <matplotlib.patches.Rectangle at 0x1325030b8>,
#   <matplotlib.patches.Rectangle at 0x132503748>,
#   <matplotlib.patches.Rectangle at 0x132503dd8>,
#   <matplotlib.patches.Rectangle at 0x13250b4a8>,
#   <matplotlib.patches.Rectangle at 0x13250bb38>,
#   <matplotlib.patches.Rectangle at 0x132516208>,
#   <matplotlib.patches.Rectangle at 0x132516898>,
#   <matplotlib.patches.Rectangle at 0x132516f28>,
#   <matplotlib.patches.Rectangle at 0x13251e5f8>,
#   <matplotlib.patches.Rectangle at 0x13251ec88>,
#   <matplotlib.patches.Rectangle at 0x132528358>,
#   <matplotlib.patches.Rectangle at 0x1325289e8>,
#   <matplotlib.patches.Rectangle at 0x1325320b8>,
#   <matplotlib.patches.Rectangle at 0x132532748>,
#   <matplotlib.patches.Rectangle at 0x132532dd8>,
#   <matplotlib.patches.Rectangle at 0x13253c4a8>,
#   <matplotlib.patches.Rectangle at 0x13253cb00>,
#   <matplotlib.patches.Rectangle at 0x132546198>,
#   <matplotlib.patches.Rectangle at 0x1325467f0>,
#   <matplotlib.patches.Rectangle at 0x132546e48>,
#   <matplotlib.patches.Rectangle at 0x1325504e0>,
#   <matplotlib.patches.Rectangle at 0x132550b38>,
#   <matplotlib.patches.Rectangle at 0x13255b1d0>,
#   <matplotlib.patches.Rectangle at 0x13255b828>,
#   <matplotlib.patches.Rectangle at 0x13255be80>,
#   <matplotlib.patches.Rectangle at 0x132563518>,
#   <matplotlib.patches.Rectangle at 0x132563b70>,
#   <matplotlib.patches.Rectangle at 0x13256f208>,
#   <matplotlib.patches.Rectangle at 0x13256f860>,
#   <matplotlib.patches.Rectangle at 0x13256feb8>,
#   <matplotlib.patches.Rectangle at 0x132576550>,
#   <matplotlib.patches.Rectangle at 0x132576ba8>,
#   <matplotlib.patches.Rectangle at 0x132581240>,
#   <matplotlib.patches.Rectangle at 0x132581898>,
#   <matplotlib.patches.Rectangle at 0x132581ef0>,
#   <matplotlib.patches.Rectangle at 0x13258d588>,
#   <matplotlib.patches.Rectangle at 0x13258dbe0>,
#   <matplotlib.patches.Rectangle at 0x132597278>,
#   <matplotlib.patches.Rectangle at 0x1325978d0>,
#   <matplotlib.patches.Rectangle at 0x132597f28>,
#   <matplotlib.patches.Rectangle at 0x13259f5c0>,
#   <matplotlib.patches.Rectangle at 0x13259fc18>,
#   <matplotlib.patches.Rectangle at 0x1325ab2b0>,
#   <matplotlib.patches.Rectangle at 0x1325ab908>,
#   <matplotlib.patches.Rectangle at 0x1325abf60>,
#   <matplotlib.patches.Rectangle at 0x1325b55f8>,
#   <matplotlib.patches.Rectangle at 0x1325b5c50>,
#   <matplotlib.patches.Rectangle at 0x13329c2e8>,
#   <matplotlib.patches.Rectangle at 0x13329c940>,
#   <matplotlib.patches.Rectangle at 0x13329cf98>,
#   <matplotlib.patches.Rectangle at 0x1332a5630>,
#   <matplotlib.patches.Rectangle at 0x1332a5c88>,
#   <matplotlib.patches.Rectangle at 0x1332ad320>,
#   <matplotlib.patches.Rectangle at 0x1332ad978>,
#   <matplotlib.patches.Rectangle at 0x1332adfd0>,
#   <matplotlib.patches.Rectangle at 0x1332b9668>,
#   <matplotlib.patches.Rectangle at 0x1332b9cc0>,
#   <matplotlib.patches.Rectangle at 0x1332c2358>,
#   <matplotlib.patches.Rectangle at 0x1332c29b0>,
#   <matplotlib.patches.Rectangle at 0x1332ce048>,
#   <matplotlib.patches.Rectangle at 0x1332ce6a0>,
#   <matplotlib.patches.Rectangle at 0x1332cecf8>,
#   <matplotlib.patches.Rectangle at 0x1332d8390>,
#   <matplotlib.patches.Rectangle at 0x1332d89e8>,
#   <matplotlib.patches.Rectangle at 0x1332e2080>,
#   <matplotlib.patches.Rectangle at 0x1332e26d8>,
#   <matplotlib.patches.Rectangle at 0x1332e2d30>,
#   <matplotlib.patches.Rectangle at 0x1332eb3c8>,
#   <matplotlib.patches.Rectangle at 0x1332eba20>,
#   <matplotlib.patches.Rectangle at 0x1332f40b8>,
#   <matplotlib.patches.Rectangle at 0x1332f4710>,
#   <matplotlib.patches.Rectangle at 0x1332f4d68>,
#   <matplotlib.patches.Rectangle at 0x1332fd400>,
#   <matplotlib.patches.Rectangle at 0x1332fda58>,
#   <matplotlib.patches.Rectangle at 0x1333080f0>,
#   <matplotlib.patches.Rectangle at 0x133308748>,
#   <matplotlib.patches.Rectangle at 0x133308da0>,
#   <matplotlib.patches.Rectangle at 0x133314438>,
#   <matplotlib.patches.Rectangle at 0x133314a90>,
#   <matplotlib.patches.Rectangle at 0x13331d128>,
#   <matplotlib.patches.Rectangle at 0x13331d780>,
#   <matplotlib.patches.Rectangle at 0x13331ddd8>,
#   <matplotlib.patches.Rectangle at 0x133328470>,
#   <matplotlib.patches.Rectangle at 0x133328ac8>,
#   <matplotlib.patches.Rectangle at 0x133330160>])

# %%
ax2.fill_between(df_volume.index.map(mdates.date2num), df_volume.values, 0)
