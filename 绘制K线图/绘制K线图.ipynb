# %%
# %matplotlib qt
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates
import pandas as pd
import pandas_datareader.data as web

# %%
df = pd.read_csv('tsla.csv', parse_dates=True, index_col=0)

df_ohlc = df['Adj Close'].resample('10D').ohlc()
df_volume = df['Volume'].resample('10D').sum()

# %%
df_ohlc.head()
# Out:
#                  open       high        low      close
# Date
# 2010-06-29  23.889999  23.889999  15.800000  17.459999
# 2010-07-09  17.400000  20.639999  17.049999  20.639999
# 2010-07-19  21.910000  21.910000  20.219999  20.719999
# 2010-07-29  20.350000  21.950001  19.590000  19.590000
# 2010-08-08  19.600000  19.600000  17.600000  19.150000

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1),(5,0), rowspan=5, colspan=1, sharex=ax1)

# %%
df_ohlc.reset_index(inplace=True)

# %%
df_ohlc.head()
# Out:
#         Date       open       high        low      close
# 0 2010-06-29  23.889999  23.889999  15.800000  17.459999
# 1 2010-07-09  17.400000  20.639999  17.049999  20.639999
# 2 2010-07-19  21.910000  21.910000  20.219999  20.719999
# 3 2010-07-29  20.350000  21.950001  19.590000  19.590000
# 4 2010-08-08  19.600000  19.600000  17.600000  19.150000

# %%
df_ohlc['Date'] = df_ohlc['Date'].map(mdates.date2num)

# %%
df_ohlc.head()
# Out:
#        Date       open       high        low      close
# 0  733952.0  23.889999  23.889999  15.800000  17.459999
# 1  733962.0  17.400000  20.639999  17.049999  20.639999
# 2  733972.0  21.910000  21.910000  20.219999  20.719999
# 3  733982.0  20.350000  21.950001  19.590000  19.590000
# 4  733992.0  19.600000  19.600000  17.600000  19.150000

# %%
ax1.xaxis_date()

# %%
candlestick_ohlc(ax1, df_ohlc.values, width=2, colorup='r', colordown='g')
# Out:
# ([<matplotlib.lines.Line2D at 0x131c02d30>,
#   <matplotlib.lines.Line2D at 0x131bac1d0>,
#   <matplotlib.lines.Line2D at 0x131c03710>,
#   <matplotlib.lines.Line2D at 0x131c03d30>,
#   <matplotlib.lines.Line2D at 0x13188a668>,
#   <matplotlib.lines.Line2D at 0x131c079e8>,
#   <matplotlib.lines.Line2D at 0x131ded9e8>,
#   <matplotlib.lines.Line2D at 0x131dedfd0>,
#   <matplotlib.lines.Line2D at 0x131d226a0>,
#   <matplotlib.lines.Line2D at 0x131d22cf8>,
#   <matplotlib.lines.Line2D at 0x131dac390>,
#   <matplotlib.lines.Line2D at 0x131dac9e8>,
#   <matplotlib.lines.Line2D at 0x131daceb8>,
#   <matplotlib.lines.Line2D at 0x131dba6d8>,
#   <matplotlib.lines.Line2D at 0x131dbad30>,
#   <matplotlib.lines.Line2D at 0x131dc43c8>,
#   <matplotlib.lines.Line2D at 0x131dc4a20>,
#   <matplotlib.lines.Line2D at 0x131dc4ef0>,
#   <matplotlib.lines.Line2D at 0x131dd4710>,
#   <matplotlib.lines.Line2D at 0x131dd4d68>,
#   <matplotlib.lines.Line2D at 0x131c6c400>,
#   <matplotlib.lines.Line2D at 0x131c6ca58>,
#   <matplotlib.lines.Line2D at 0x131c6cf28>,
#   <matplotlib.lines.Line2D at 0x131c7b748>,
#   <matplotlib.lines.Line2D at 0x131c7bda0>,
#   <matplotlib.lines.Line2D at 0x131c8c438>,
#   <matplotlib.lines.Line2D at 0x131c8ca90>,
#   <matplotlib.lines.Line2D at 0x131c8cf60>,
#   <matplotlib.lines.Line2D at 0x131c9f780>,
#   <matplotlib.lines.Line2D at 0x131c9fdd8>,
#   <matplotlib.lines.Line2D at 0x131cb3470>,
#   <matplotlib.lines.Line2D at 0x131cb3ac8>,
#   <matplotlib.lines.Line2D at 0x131cb3f98>,
#   <matplotlib.lines.Line2D at 0x131cc77b8>,
#   <matplotlib.lines.Line2D at 0x131cc7e10>,
#   <matplotlib.lines.Line2D at 0x131cd84a8>,
#   <matplotlib.lines.Line2D at 0x131cd8b00>,
#   <matplotlib.lines.Line2D at 0x131cd8fd0>,
#   <matplotlib.lines.Line2D at 0x131ce87f0>,
#   <matplotlib.lines.Line2D at 0x131ce8e48>,
#   <matplotlib.lines.Line2D at 0x131d7d4e0>,
#   <matplotlib.lines.Line2D at 0x131d7db38>,
#   <matplotlib.lines.Line2D at 0x131d7dfd0>,
#   <matplotlib.lines.Line2D at 0x131d8a828>,
#   <matplotlib.lines.Line2D at 0x131d8ae80>,
#   <matplotlib.lines.Line2D at 0x131d9c518>,
#   <matplotlib.lines.Line2D at 0x131d9cb70>,
#   <matplotlib.lines.Line2D at 0x131c31208>,
#   <matplotlib.lines.Line2D at 0x131c31860>,
#   <matplotlib.lines.Line2D at 0x131c31eb8>,
#   <matplotlib.lines.Line2D at 0x131c41550>,
#   <matplotlib.lines.Line2D at 0x131c41ba8>,
#   <matplotlib.lines.Line2D at 0x131c5b240>,
#   <matplotlib.lines.Line2D at 0x131c5b898>,
#   <matplotlib.lines.Line2D at 0x131c5bef0>,
#   <matplotlib.lines.Line2D at 0x131d2f588>,
#   <matplotlib.lines.Line2D at 0x131d2fbe0>,
#   <matplotlib.lines.Line2D at 0x131d41278>,
#   <matplotlib.lines.Line2D at 0x131d418d0>,
#   <matplotlib.lines.Line2D at 0x131d41f28>,
#   <matplotlib.lines.Line2D at 0x131d595c0>,
#   <matplotlib.lines.Line2D at 0x131d59c18>,
#   <matplotlib.lines.Line2D at 0x131e012b0>,
#   <matplotlib.lines.Line2D at 0x131e01908>,
#   <matplotlib.lines.Line2D at 0x131e01f60>,
#   <matplotlib.lines.Line2D at 0x131e0e5f8>,
#   <matplotlib.lines.Line2D at 0x131e0ec50>,
#   <matplotlib.lines.Line2D at 0x131e182e8>,
#   <matplotlib.lines.Line2D at 0x131e18940>,
#   <matplotlib.lines.Line2D at 0x131e18f98>,
#   <matplotlib.lines.Line2D at 0x131e21630>,
#   <matplotlib.lines.Line2D at 0x131e21c88>,
#   <matplotlib.lines.Line2D at 0x131e2b320>,
#   <matplotlib.lines.Line2D at 0x131e2b978>,
#   <matplotlib.lines.Line2D at 0x131e2bfd0>,
#   <matplotlib.lines.Line2D at 0x131e34668>,
#   <matplotlib.lines.Line2D at 0x131e34cc0>,
#   <matplotlib.lines.Line2D at 0x131e3d358>,
#   <matplotlib.lines.Line2D at 0x131e3d9b0>,
#   <matplotlib.lines.Line2D at 0x131e3dfd0>,
#   <matplotlib.lines.Line2D at 0x131e4a6a0>,
#   <matplotlib.lines.Line2D at 0x131e4acf8>,
#   <matplotlib.lines.Line2D at 0x131e53390>,
#   <matplotlib.lines.Line2D at 0x131e539e8>,
#   <matplotlib.lines.Line2D at 0x131e53eb8>,
#   <matplotlib.lines.Line2D at 0x131e5f6d8>,
#   <matplotlib.lines.Line2D at 0x131e5fd30>,
#   <matplotlib.lines.Line2D at 0x131e673c8>,
#   <matplotlib.lines.Line2D at 0x131e67a20>,
#   <matplotlib.lines.Line2D at 0x131e67ef0>,
#   <matplotlib.lines.Line2D at 0x131e72710>,
#   <matplotlib.lines.Line2D at 0x131e72d68>,
#   <matplotlib.lines.Line2D at 0x131e7c400>,
#   <matplotlib.lines.Line2D at 0x131e7ca58>,
#   <matplotlib.lines.Line2D at 0x131e7cf28>,
#   <matplotlib.lines.Line2D at 0x131e85748>,
#   <matplotlib.lines.Line2D at 0x131e85da0>,
#   <matplotlib.lines.Line2D at 0x131e8f438>,
#   <matplotlib.lines.Line2D at 0x131e8fa90>,
#   <matplotlib.lines.Line2D at 0x131e8ff60>,
#   <matplotlib.lines.Line2D at 0x131e99780>,
#   <matplotlib.lines.Line2D at 0x131e99dd8>,
#   <matplotlib.lines.Line2D at 0x131ea4470>,
#   <matplotlib.lines.Line2D at 0x131ea4ac8>,
#   <matplotlib.lines.Line2D at 0x131ea4f98>,
#   <matplotlib.lines.Line2D at 0x131eb07b8>,
#   <matplotlib.lines.Line2D at 0x131eb0e10>,
#   <matplotlib.lines.Line2D at 0x131eb84a8>,
#   <matplotlib.lines.Line2D at 0x131eb8b00>,
#   <matplotlib.lines.Line2D at 0x131eb8fd0>,
#   <matplotlib.lines.Line2D at 0x131ec37f0>,
#   <matplotlib.lines.Line2D at 0x131ec3e48>,
#   <matplotlib.lines.Line2D at 0x131ecd4e0>,
#   <matplotlib.lines.Line2D at 0x131ecdb38>,
#   <matplotlib.lines.Line2D at 0x131ecdfd0>,
#   <matplotlib.lines.Line2D at 0x131ed6828>,
#   <matplotlib.lines.Line2D at 0x131ed6e80>,
#   <matplotlib.lines.Line2D at 0x131ede518>,
#   <matplotlib.lines.Line2D at 0x131edeb70>,
#   <matplotlib.lines.Line2D at 0x131eea208>,
#   <matplotlib.lines.Line2D at 0x131eea860>,
#   <matplotlib.lines.Line2D at 0x131eeaeb8>,
#   <matplotlib.lines.Line2D at 0x131ef3550>,
#   <matplotlib.lines.Line2D at 0x131ef3ba8>,
#   <matplotlib.lines.Line2D at 0x131f00240>,
#   <matplotlib.lines.Line2D at 0x131f00898>,
#   <matplotlib.lines.Line2D at 0x131f00ef0>,
#   <matplotlib.lines.Line2D at 0x131f0a588>,
#   <matplotlib.lines.Line2D at 0x131f0abe0>,
#   <matplotlib.lines.Line2D at 0x131f12278>,
#   <matplotlib.lines.Line2D at 0x131f128d0>,
#   <matplotlib.lines.Line2D at 0x131f12f28>,
#   <matplotlib.lines.Line2D at 0x131f1c5c0>,
#   <matplotlib.lines.Line2D at 0x131f1cc18>,
#   <matplotlib.lines.Line2D at 0x131f252b0>,
#   <matplotlib.lines.Line2D at 0x131f25908>,
#   <matplotlib.lines.Line2D at 0x131f25f60>,
#   <matplotlib.lines.Line2D at 0x131f315f8>,
#   <matplotlib.lines.Line2D at 0x131f31c50>,
#   <matplotlib.lines.Line2D at 0x131f3c2e8>,
#   <matplotlib.lines.Line2D at 0x131f3c940>,
#   <matplotlib.lines.Line2D at 0x131f3cf98>,
#   <matplotlib.lines.Line2D at 0x131f44630>,
#   <matplotlib.lines.Line2D at 0x131f44c88>,
#   <matplotlib.lines.Line2D at 0x131f4e320>,
#   <matplotlib.lines.Line2D at 0x131f4e978>,
#   <matplotlib.lines.Line2D at 0x131f4efd0>,
#   <matplotlib.lines.Line2D at 0x131f5a668>,
#   <matplotlib.lines.Line2D at 0x131f5acc0>,
#   <matplotlib.lines.Line2D at 0x131f63358>,
#   <matplotlib.lines.Line2D at 0x131f639b0>,
#   <matplotlib.lines.Line2D at 0x131f63fd0>,
#   <matplotlib.lines.Line2D at 0x131f6d6a0>,
#   <matplotlib.lines.Line2D at 0x131f6dcf8>,
#   <matplotlib.lines.Line2D at 0x131f77390>,
#   <matplotlib.lines.Line2D at 0x131f779e8>,
#   <matplotlib.lines.Line2D at 0x131f77eb8>,
#   <matplotlib.lines.Line2D at 0x131f806d8>,
#   <matplotlib.lines.Line2D at 0x131f80d30>,
#   <matplotlib.lines.Line2D at 0x131f8b3c8>,
#   <matplotlib.lines.Line2D at 0x131f8ba20>,
#   <matplotlib.lines.Line2D at 0x131f8bef0>,
#   <matplotlib.lines.Line2D at 0x131f95710>,
#   <matplotlib.lines.Line2D at 0x131f95d68>,
#   <matplotlib.lines.Line2D at 0x131f9f400>,
#   <matplotlib.lines.Line2D at 0x131f9fa58>,
#   <matplotlib.lines.Line2D at 0x131f9ff28>,
#   <matplotlib.lines.Line2D at 0x131fab748>,
#   <matplotlib.lines.Line2D at 0x131fabda0>,
#   <matplotlib.lines.Line2D at 0x131fb3438>,
#   <matplotlib.lines.Line2D at 0x131fb3a90>,
#   <matplotlib.lines.Line2D at 0x131fb3f60>,
#   <matplotlib.lines.Line2D at 0x131fbe780>,
#   <matplotlib.lines.Line2D at 0x131fbedd8>,
#   <matplotlib.lines.Line2D at 0x131fc8470>,
#   <matplotlib.lines.Line2D at 0x131fc8ac8>,
#   <matplotlib.lines.Line2D at 0x131fc8f98>,
#   <matplotlib.lines.Line2D at 0x131fd37b8>,
#   <matplotlib.lines.Line2D at 0x131fd3e10>,
#   <matplotlib.lines.Line2D at 0x131fdb4a8>,
#   <matplotlib.lines.Line2D at 0x131fdbb00>,
#   <matplotlib.lines.Line2D at 0x131fdbfd0>,
#   <matplotlib.lines.Line2D at 0x131fe77f0>,
#   <matplotlib.lines.Line2D at 0x131fe7e48>,
#   <matplotlib.lines.Line2D at 0x131ff04e0>,
#   <matplotlib.lines.Line2D at 0x131ff0b38>,
#   <matplotlib.lines.Line2D at 0x131ff0fd0>,
#   <matplotlib.lines.Line2D at 0x131ffa828>,
#   <matplotlib.lines.Line2D at 0x131ffae80>,
#   <matplotlib.lines.Line2D at 0x132005518>,
#   <matplotlib.lines.Line2D at 0x132005b70>,
#   <matplotlib.lines.Line2D at 0x13200f208>,
#   <matplotlib.lines.Line2D at 0x13200f860>,
#   <matplotlib.lines.Line2D at 0x13200feb8>,
#   <matplotlib.lines.Line2D at 0x132019550>,
#   <matplotlib.lines.Line2D at 0x132019ba8>,
#   <matplotlib.lines.Line2D at 0x132023240>,
#   <matplotlib.lines.Line2D at 0x132023898>,
#   <matplotlib.lines.Line2D at 0x132023ef0>,
#   <matplotlib.lines.Line2D at 0x13202c588>,
#   <matplotlib.lines.Line2D at 0x13202cbe0>,
#   <matplotlib.lines.Line2D at 0x132036278>,
#   <matplotlib.lines.Line2D at 0x1320368d0>,
#   <matplotlib.lines.Line2D at 0x132036f28>,
#   <matplotlib.lines.Line2D at 0x1320415c0>,
#   <matplotlib.lines.Line2D at 0x132041c18>,
#   <matplotlib.lines.Line2D at 0x13204b2b0>,
#   <matplotlib.lines.Line2D at 0x13204b908>,
#   <matplotlib.lines.Line2D at 0x13204bf60>,
#   <matplotlib.lines.Line2D at 0x1320565f8>,
#   <matplotlib.lines.Line2D at 0x132056c50>,
#   <matplotlib.lines.Line2D at 0x1320602e8>,
#   <matplotlib.lines.Line2D at 0x132060940>,
#   <matplotlib.lines.Line2D at 0x132060f98>,
#   <matplotlib.lines.Line2D at 0x13206a630>,
#   <matplotlib.lines.Line2D at 0x13206ac88>,
#   <matplotlib.lines.Line2D at 0x132074320>,
#   <matplotlib.lines.Line2D at 0x132074978>,
#   <matplotlib.lines.Line2D at 0x132074fd0>,
#   <matplotlib.lines.Line2D at 0x13207d668>,
#   <matplotlib.lines.Line2D at 0x13207dcc0>,
#   <matplotlib.lines.Line2D at 0x132085358>,
#   <matplotlib.lines.Line2D at 0x1320859b0>,
#   <matplotlib.lines.Line2D at 0x132085fd0>,
#   <matplotlib.lines.Line2D at 0x1320906a0>,
#   <matplotlib.lines.Line2D at 0x132090cf8>,
#   <matplotlib.lines.Line2D at 0x13209b390>,
#   <matplotlib.lines.Line2D at 0x13209b9e8>,
#   <matplotlib.lines.Line2D at 0x13209beb8>,
#   <matplotlib.lines.Line2D at 0x1320a66d8>,
#   <matplotlib.lines.Line2D at 0x1320a6d30>,
#   <matplotlib.lines.Line2D at 0x1320b23c8>,
#   <matplotlib.lines.Line2D at 0x1320b2a20>,
#   <matplotlib.lines.Line2D at 0x1320b2ef0>,
#   <matplotlib.lines.Line2D at 0x1320ba710>,
#   <matplotlib.lines.Line2D at 0x1320bad68>,
#   <matplotlib.lines.Line2D at 0x1320c5400>,
#   <matplotlib.lines.Line2D at 0x1320c5a58>],
#  [<matplotlib.patches.Rectangle at 0x131bac5c0>,
#   <matplotlib.patches.Rectangle at 0x131bf1d68>,
#   <matplotlib.patches.Rectangle at 0x131c038d0>,
#   <matplotlib.patches.Rectangle at 0x131c03ef0>,
#   <matplotlib.patches.Rectangle at 0x131c07550>,
#   <matplotlib.patches.Rectangle at 0x131c154e0>,
#   <matplotlib.patches.Rectangle at 0x131dedba8>,
#   <matplotlib.patches.Rectangle at 0x131d22208>,
#   <matplotlib.patches.Rectangle at 0x131d22860>,
#   <matplotlib.patches.Rectangle at 0x131d22eb8>,
#   <matplotlib.patches.Rectangle at 0x131dac550>,
#   <matplotlib.patches.Rectangle at 0x131dacba8>,
#   <matplotlib.patches.Rectangle at 0x131dba240>,
#   <matplotlib.patches.Rectangle at 0x131dba898>,
#   <matplotlib.patches.Rectangle at 0x131dbaef0>,
#   <matplotlib.patches.Rectangle at 0x131dc4588>,
#   <matplotlib.patches.Rectangle at 0x131dc4be0>,
#   <matplotlib.patches.Rectangle at 0x131dd4278>,
#   <matplotlib.patches.Rectangle at 0x131dd48d0>,
#   <matplotlib.patches.Rectangle at 0x131dd4f28>,
#   <matplotlib.patches.Rectangle at 0x131c6c5c0>,
#   <matplotlib.patches.Rectangle at 0x131c6cc18>,
#   <matplotlib.patches.Rectangle at 0x131c7b2b0>,
#   <matplotlib.patches.Rectangle at 0x131c7b908>,
#   <matplotlib.patches.Rectangle at 0x131c7bf60>,
#   <matplotlib.patches.Rectangle at 0x131c8c5f8>,
#   <matplotlib.patches.Rectangle at 0x131c8cc50>,
#   <matplotlib.patches.Rectangle at 0x131c9f2e8>,
#   <matplotlib.patches.Rectangle at 0x131c9f940>,
#   <matplotlib.patches.Rectangle at 0x131c9ff98>,
#   <matplotlib.patches.Rectangle at 0x131cb3630>,
#   <matplotlib.patches.Rectangle at 0x131cb3c88>,
#   <matplotlib.patches.Rectangle at 0x131cc7320>,
#   <matplotlib.patches.Rectangle at 0x131cc7978>,
#   <matplotlib.patches.Rectangle at 0x131cc7fd0>,
#   <matplotlib.patches.Rectangle at 0x131cd8668>,
#   <matplotlib.patches.Rectangle at 0x131cd8cc0>,
#   <matplotlib.patches.Rectangle at 0x131ce8358>,
#   <matplotlib.patches.Rectangle at 0x131ce89b0>,
#   <matplotlib.patches.Rectangle at 0x131d7d048>,
#   <matplotlib.patches.Rectangle at 0x131d7d6a0>,
#   <matplotlib.patches.Rectangle at 0x131d7dcf8>,
#   <matplotlib.patches.Rectangle at 0x131d8a390>,
#   <matplotlib.patches.Rectangle at 0x131d8a9e8>,
#   <matplotlib.patches.Rectangle at 0x131d9c080>,
#   <matplotlib.patches.Rectangle at 0x131d9c6d8>,
#   <matplotlib.patches.Rectangle at 0x131d9cd30>,
#   <matplotlib.patches.Rectangle at 0x131c313c8>,
#   <matplotlib.patches.Rectangle at 0x131c31a20>,
#   <matplotlib.patches.Rectangle at 0x131c410b8>,
#   <matplotlib.patches.Rectangle at 0x131c41710>,
#   <matplotlib.patches.Rectangle at 0x131c41d68>,
#   <matplotlib.patches.Rectangle at 0x131c5b400>,
#   <matplotlib.patches.Rectangle at 0x131c5ba58>,
#   <matplotlib.patches.Rectangle at 0x131d2f0f0>,
#   <matplotlib.patches.Rectangle at 0x131d2f748>,
#   <matplotlib.patches.Rectangle at 0x131d2fda0>,
#   <matplotlib.patches.Rectangle at 0x131d41438>,
#   <matplotlib.patches.Rectangle at 0x131d41a90>,
#   <matplotlib.patches.Rectangle at 0x131d59128>,
#   <matplotlib.patches.Rectangle at 0x131d59780>,
#   <matplotlib.patches.Rectangle at 0x131d59dd8>,
#   <matplotlib.patches.Rectangle at 0x131e01470>,
#   <matplotlib.patches.Rectangle at 0x131e01ac8>,
#   <matplotlib.patches.Rectangle at 0x131e0e160>,
#   <matplotlib.patches.Rectangle at 0x131e0e7b8>,
#   <matplotlib.patches.Rectangle at 0x131e0ee10>,
#   <matplotlib.patches.Rectangle at 0x131e184a8>,
#   <matplotlib.patches.Rectangle at 0x131e18b00>,
#   <matplotlib.patches.Rectangle at 0x131e21198>,
#   <matplotlib.patches.Rectangle at 0x131e217f0>,
#   <matplotlib.patches.Rectangle at 0x131e21e48>,
#   <matplotlib.patches.Rectangle at 0x131e2b4e0>,
#   <matplotlib.patches.Rectangle at 0x131e2bb38>,
#   <matplotlib.patches.Rectangle at 0x131e341d0>,
#   <matplotlib.patches.Rectangle at 0x131e34828>,
#   <matplotlib.patches.Rectangle at 0x131e34e80>,
#   <matplotlib.patches.Rectangle at 0x131e3d518>,
#   <matplotlib.patches.Rectangle at 0x131e3db70>,
#   <matplotlib.patches.Rectangle at 0x131e4a208>,
#   <matplotlib.patches.Rectangle at 0x131e4a860>,
#   <matplotlib.patches.Rectangle at 0x131e4aeb8>,
#   <matplotlib.patches.Rectangle at 0x131e53550>,
#   <matplotlib.patches.Rectangle at 0x131e53ba8>,
#   <matplotlib.patches.Rectangle at 0x131e5f240>,
#   <matplotlib.patches.Rectangle at 0x131e5f898>,
#   <matplotlib.patches.Rectangle at 0x131e5fef0>,
#   <matplotlib.patches.Rectangle at 0x131e67588>,
#   <matplotlib.patches.Rectangle at 0x131e67be0>,
#   <matplotlib.patches.Rectangle at 0x131e72278>,
#   <matplotlib.patches.Rectangle at 0x131e728d0>,
#   <matplotlib.patches.Rectangle at 0x131e72f28>,
#   <matplotlib.patches.Rectangle at 0x131e7c5c0>,
#   <matplotlib.patches.Rectangle at 0x131e7cc18>,
#   <matplotlib.patches.Rectangle at 0x131e852b0>,
#   <matplotlib.patches.Rectangle at 0x131e85908>,
#   <matplotlib.patches.Rectangle at 0x131e85f60>,
#   <matplotlib.patches.Rectangle at 0x131e8f5f8>,
#   <matplotlib.patches.Rectangle at 0x131e8fc50>,
#   <matplotlib.patches.Rectangle at 0x131e992e8>,
#   <matplotlib.patches.Rectangle at 0x131e99940>,
#   <matplotlib.patches.Rectangle at 0x131e99f98>,
#   <matplotlib.patches.Rectangle at 0x131ea4630>,
#   <matplotlib.patches.Rectangle at 0x131ea4c88>,
#   <matplotlib.patches.Rectangle at 0x131eb0320>,
#   <matplotlib.patches.Rectangle at 0x131eb0978>,
#   <matplotlib.patches.Rectangle at 0x131eb0fd0>,
#   <matplotlib.patches.Rectangle at 0x131eb8668>,
#   <matplotlib.patches.Rectangle at 0x131eb8cc0>,
#   <matplotlib.patches.Rectangle at 0x131ec3358>,
#   <matplotlib.patches.Rectangle at 0x131ec39b0>,
#   <matplotlib.patches.Rectangle at 0x131ecd048>,
#   <matplotlib.patches.Rectangle at 0x131ecd6a0>,
#   <matplotlib.patches.Rectangle at 0x131ecdcf8>,
#   <matplotlib.patches.Rectangle at 0x131ed6390>,
#   <matplotlib.patches.Rectangle at 0x131ed69e8>,
#   <matplotlib.patches.Rectangle at 0x131ede080>,
#   <matplotlib.patches.Rectangle at 0x131ede6d8>,
#   <matplotlib.patches.Rectangle at 0x131eded30>,
#   <matplotlib.patches.Rectangle at 0x131eea3c8>,
#   <matplotlib.patches.Rectangle at 0x131eeaa20>,
#   <matplotlib.patches.Rectangle at 0x131ef30b8>,
#   <matplotlib.patches.Rectangle at 0x131ef3710>,
#   <matplotlib.patches.Rectangle at 0x131ef3d68>,
#   <matplotlib.patches.Rectangle at 0x131f00400>,
#   <matplotlib.patches.Rectangle at 0x131f00a58>,
#   <matplotlib.patches.Rectangle at 0x131f0a0f0>,
#   <matplotlib.patches.Rectangle at 0x131f0a748>,
#   <matplotlib.patches.Rectangle at 0x131f0ada0>,
#   <matplotlib.patches.Rectangle at 0x131f12438>,
#   <matplotlib.patches.Rectangle at 0x131f12a90>,
#   <matplotlib.patches.Rectangle at 0x131f1c128>,
#   <matplotlib.patches.Rectangle at 0x131f1c780>,
#   <matplotlib.patches.Rectangle at 0x131f1cdd8>,
#   <matplotlib.patches.Rectangle at 0x131f25470>,
#   <matplotlib.patches.Rectangle at 0x131f25ac8>,
#   <matplotlib.patches.Rectangle at 0x131f31160>,
#   <matplotlib.patches.Rectangle at 0x131f317b8>,
#   <matplotlib.patches.Rectangle at 0x131f31e10>,
#   <matplotlib.patches.Rectangle at 0x131f3c4a8>,
#   <matplotlib.patches.Rectangle at 0x131f3cb00>,
#   <matplotlib.patches.Rectangle at 0x131f44198>,
#   <matplotlib.patches.Rectangle at 0x131f447f0>,
#   <matplotlib.patches.Rectangle at 0x131f44e48>,
#   <matplotlib.patches.Rectangle at 0x131f4e4e0>,
#   <matplotlib.patches.Rectangle at 0x131f4eb38>,
#   <matplotlib.patches.Rectangle at 0x131f5a1d0>,
#   <matplotlib.patches.Rectangle at 0x131f5a828>,
#   <matplotlib.patches.Rectangle at 0x131f5ae80>,
#   <matplotlib.patches.Rectangle at 0x131f63518>,
#   <matplotlib.patches.Rectangle at 0x131f63b70>,
#   <matplotlib.patches.Rectangle at 0x131f6d208>,
#   <matplotlib.patches.Rectangle at 0x131f6d860>,
#   <matplotlib.patches.Rectangle at 0x131f6deb8>,
#   <matplotlib.patches.Rectangle at 0x131f77550>,
#   <matplotlib.patches.Rectangle at 0x131f77ba8>,
#   <matplotlib.patches.Rectangle at 0x131f80240>,
#   <matplotlib.patches.Rectangle at 0x131f80898>,
#   <matplotlib.patches.Rectangle at 0x131f80ef0>,
#   <matplotlib.patches.Rectangle at 0x131f8b588>,
#   <matplotlib.patches.Rectangle at 0x131f8bbe0>,
#   <matplotlib.patches.Rectangle at 0x131f95278>,
#   <matplotlib.patches.Rectangle at 0x131f958d0>,
#   <matplotlib.patches.Rectangle at 0x131f95f28>,
#   <matplotlib.patches.Rectangle at 0x131f9f5c0>,
#   <matplotlib.patches.Rectangle at 0x131f9fc18>,
#   <matplotlib.patches.Rectangle at 0x131fab2b0>,
#   <matplotlib.patches.Rectangle at 0x131fab908>,
#   <matplotlib.patches.Rectangle at 0x131fabf60>,
#   <matplotlib.patches.Rectangle at 0x131fb35f8>,
#   <matplotlib.patches.Rectangle at 0x131fb3c50>,
#   <matplotlib.patches.Rectangle at 0x131fbe2e8>,
#   <matplotlib.patches.Rectangle at 0x131fbe940>,
#   <matplotlib.patches.Rectangle at 0x131fbef98>,
#   <matplotlib.patches.Rectangle at 0x131fc8630>,
#   <matplotlib.patches.Rectangle at 0x131fc8c88>,
#   <matplotlib.patches.Rectangle at 0x131fd3320>,
#   <matplotlib.patches.Rectangle at 0x131fd3978>,
#   <matplotlib.patches.Rectangle at 0x131fd3fd0>,
#   <matplotlib.patches.Rectangle at 0x131fdb668>,
#   <matplotlib.patches.Rectangle at 0x131fdbcc0>,
#   <matplotlib.patches.Rectangle at 0x131fe7358>,
#   <matplotlib.patches.Rectangle at 0x131fe79b0>,
#   <matplotlib.patches.Rectangle at 0x131ff0048>,
#   <matplotlib.patches.Rectangle at 0x131ff06a0>,
#   <matplotlib.patches.Rectangle at 0x131ff0cf8>,
#   <matplotlib.patches.Rectangle at 0x131ffa390>,
#   <matplotlib.patches.Rectangle at 0x131ffa9e8>,
#   <matplotlib.patches.Rectangle at 0x132005080>,
#   <matplotlib.patches.Rectangle at 0x1320056d8>,
#   <matplotlib.patches.Rectangle at 0x132005d30>,
#   <matplotlib.patches.Rectangle at 0x13200f3c8>,
#   <matplotlib.patches.Rectangle at 0x13200fa20>,
#   <matplotlib.patches.Rectangle at 0x1320190b8>,
#   <matplotlib.patches.Rectangle at 0x132019710>,
#   <matplotlib.patches.Rectangle at 0x132019d68>,
#   <matplotlib.patches.Rectangle at 0x132023400>,
#   <matplotlib.patches.Rectangle at 0x132023a58>,
#   <matplotlib.patches.Rectangle at 0x13202c0f0>,
#   <matplotlib.patches.Rectangle at 0x13202c748>,
#   <matplotlib.patches.Rectangle at 0x13202cda0>,
#   <matplotlib.patches.Rectangle at 0x132036438>,
#   <matplotlib.patches.Rectangle at 0x132036a90>,
#   <matplotlib.patches.Rectangle at 0x132041128>,
#   <matplotlib.patches.Rectangle at 0x132041780>,
#   <matplotlib.patches.Rectangle at 0x132041dd8>,
#   <matplotlib.patches.Rectangle at 0x13204b470>,
#   <matplotlib.patches.Rectangle at 0x13204bac8>,
#   <matplotlib.patches.Rectangle at 0x132056160>,
#   <matplotlib.patches.Rectangle at 0x1320567b8>,
#   <matplotlib.patches.Rectangle at 0x132056e10>,
#   <matplotlib.patches.Rectangle at 0x1320604a8>,
#   <matplotlib.patches.Rectangle at 0x132060b00>,
#   <matplotlib.patches.Rectangle at 0x13206a198>,
#   <matplotlib.patches.Rectangle at 0x13206a7f0>,
#   <matplotlib.patches.Rectangle at 0x13206ae48>,
#   <matplotlib.patches.Rectangle at 0x1320744e0>,
#   <matplotlib.patches.Rectangle at 0x132074b38>,
#   <matplotlib.patches.Rectangle at 0x13207d1d0>,
#   <matplotlib.patches.Rectangle at 0x13207d828>,
#   <matplotlib.patches.Rectangle at 0x13207de80>,
#   <matplotlib.patches.Rectangle at 0x132085518>,
#   <matplotlib.patches.Rectangle at 0x132085b70>,
#   <matplotlib.patches.Rectangle at 0x132090208>,
#   <matplotlib.patches.Rectangle at 0x132090860>,
#   <matplotlib.patches.Rectangle at 0x132090eb8>,
#   <matplotlib.patches.Rectangle at 0x13209b550>,
#   <matplotlib.patches.Rectangle at 0x13209bba8>,
#   <matplotlib.patches.Rectangle at 0x1320a6240>,
#   <matplotlib.patches.Rectangle at 0x1320a6898>,
#   <matplotlib.patches.Rectangle at 0x1320a6ef0>,
#   <matplotlib.patches.Rectangle at 0x1320b2588>,
#   <matplotlib.patches.Rectangle at 0x1320b2be0>,
#   <matplotlib.patches.Rectangle at 0x1320ba278>,
#   <matplotlib.patches.Rectangle at 0x1320ba8d0>,
#   <matplotlib.patches.Rectangle at 0x1320baf28>,
#   <matplotlib.patches.Rectangle at 0x1320c55c0>,
#   <matplotlib.patches.Rectangle at 0x1320c5c18>])

# %%
ax2.fill_between(df_volume.index.map(mdates.date2num), df_volume.values, 0)
