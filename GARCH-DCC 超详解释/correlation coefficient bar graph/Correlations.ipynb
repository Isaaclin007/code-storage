# %%
import pandas as pd 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_bcom_raw = pd.read_excel('BCOM Index (OHLC).xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_bcom_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-07  90.7495     NaN       NaN  90.7495       NaN         NaN  90.7495
# 2000-01-06  91.0400     NaN       NaN  91.0400       NaN         NaN  91.0400
# 2000-01-05  91.0023     NaN       NaN  91.0023       NaN         NaN  91.0023
# 2000-01-04  91.4952     NaN       NaN  91.4952       NaN         NaN  91.4952
# 2000-01-03  92.0451     NaN       NaN  92.0451       NaN         NaN  92.0451
#
#             Change.2  % Change.2   PX_LOW  Change.3  % Change.3
# Date
# 2000-01-07       NaN         NaN  90.7495       NaN         NaN
# 2000-01-06       NaN         NaN  91.0400       NaN         NaN
# 2000-01-05       NaN         NaN  91.0023       NaN         NaN
# 2000-01-04       NaN         NaN  91.4952       NaN         NaN
# 2000-01-03       NaN         NaN  92.0451       NaN         NaN

# %%
df_bcom_raw
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2019-02-25  81.3010 -0.8236 -1.002866  82.2414    0.1168    0.142223  82.4778
# 2019-02-22  82.1246  0.3368  0.411797  81.7159   -0.0719   -0.087910  82.2338
# 2019-02-21  81.7878  0.1057  0.129404  81.5986   -0.0835   -0.102226  81.8750
# 2019-02-20  81.6821  0.3879  0.477156  81.4641    0.1699    0.208994  81.8110
# 2019-02-19  81.2942  0.3373  0.416641  81.1193    0.1624    0.200601  81.3327
# 2019-02-15  80.9569  0.9958  1.245356  80.0425    0.0814    0.101800  80.9639
# 2019-02-14  79.9611 -0.2030 -0.253231  80.1352   -0.0289   -0.036051  80.5106
# 2019-02-13  80.1641  0.0668  0.083399  80.2090    0.1117    0.139455  80.3939
# 2019-02-12  80.0973  0.4418  0.554638  79.8683    0.2128    0.267150  80.3066
# 2019-02-11  79.6555 -0.4100 -0.512081  79.9816   -0.0839   -0.104789  80.0945
# 2019-02-08  80.0655  0.0264  0.032984  79.9778   -0.0613   -0.076588  80.3972
# 2019-02-07  80.0391 -0.9465 -1.168726  80.8530   -0.1326   -0.163733  80.9004
# 2019-02-06  80.9856  0.1050  0.129821  80.9997    0.1191    0.147254  81.0866
# 2019-02-05  80.8806 -0.2198 -0.271022  81.2030    0.1026    0.126510  81.2581
# 2019-02-04  81.1004  0.1354  0.167233  80.9752    0.0102    0.012598  81.1935
# 2019-02-01  80.9650  0.2398  0.297057  80.6301   -0.0951   -0.117807  81.1637
# 2019-01-31  80.7252 -0.1570 -0.194109  81.1826    0.3004    0.371404  81.6194
# 2019-01-30  80.8822  0.3818  0.474283  80.5615    0.0611    0.075900  81.1392
# 2019-01-29  80.5004  0.6333  0.792942  79.8854    0.0183    0.022913  80.5548
# 2019-01-28  79.8671 -1.2022 -1.482929  80.5474   -0.5219   -0.643770  80.5817
# 2000-02-02       NaN         NaN  96.7944       NaN         NaN
# 2000-02-01       NaN         NaN  97.5493       NaN         NaN
# 2000-01-31       NaN         NaN  96.8149       NaN         NaN
# 2000-01-28       NaN         NaN  96.5136       NaN         NaN
# 2000-01-27       NaN         NaN  96.9539       NaN         NaN
# 2000-01-26       NaN         NaN  96.8450       NaN         NaN
# 2000-01-25       NaN         NaN  97.6311       NaN         NaN
# 2000-01-24       NaN         NaN  97.0482       NaN         NaN
# 2000-01-21       NaN         NaN  97.4665       NaN         NaN
# 2000-01-20       NaN         NaN  97.6501       NaN         NaN
# 2000-01-19       NaN         NaN  97.1845       NaN         NaN
# 2000-01-18       NaN         NaN  96.4478       NaN         NaN
# 2000-01-14       NaN         NaN  95.2123       NaN         NaN
# 2000-01-13       NaN         NaN  93.7982       NaN         NaN
# 2000-01-12       NaN         NaN  93.1605       NaN         NaN
# 2000-01-11       NaN         NaN  92.0480       NaN         NaN
# 2000-01-10       NaN         NaN  90.9900       NaN         NaN
# 2000-01-07       NaN         NaN  90.7495       NaN         NaN
# 2000-01-06       NaN         NaN  91.0400       NaN         NaN
# 2000-01-05       NaN         NaN  91.0023       NaN         NaN
# 2000-01-04       NaN         NaN  91.4952       NaN         NaN
# 2000-01-03       NaN         NaN  92.0451       NaN         NaN
#
# [4806 rows x 12 columns]

# %%
df_spx_raw = pd.read_excel('SPX Index (OHLC).xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
len(df_spx_raw)
df_spx_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-07  1441.47     NaN       NaN  1403.45       NaN         NaN  1441.47
# 2000-01-06  1403.45     NaN       NaN  1402.11       NaN         NaN  1411.90
# 2000-01-05  1402.11     NaN       NaN  1399.42       NaN         NaN  1413.27
# 2000-01-04  1399.42     NaN       NaN  1455.22       NaN         NaN  1455.22
# 2000-01-03  1455.22     NaN       NaN  1469.25       NaN         NaN  1478.00
#
#             Change.2  % Change.2   PX_LOW  Change.3  % Change.3
# Date
# 2000-01-07       NaN         NaN  1400.73       NaN         NaN
# 2000-01-06       NaN         NaN  1392.02       NaN         NaN
# 2000-01-05       NaN         NaN  1377.68       NaN         NaN
# 2000-01-04       NaN         NaN  1397.43       NaN         NaN
# 2000-01-03       NaN         NaN  1438.36       NaN         NaN

# %%
df_bcom_close = df_bcom_raw.PX_LAST

# %%
df_bcom_close.head()
# Out:
# Date
# 2019-02-25    81.3010
# 2019-02-22    82.1246
# 2019-02-21    81.7878
# 2019-02-20    81.6821
# 2019-02-19    81.2942
# Name: PX_LAST, dtype: float64

# %%
df_bcom_close.tail()
# Out:
# Date
# 2000-01-07    90.7495
# 2000-01-06    91.0400
# 2000-01-05    91.0023
# 2000-01-04    91.4952
# 2000-01-03    92.0451
# Name: PX_LAST, dtype: float64

# %%
df_spx_close = df_spx_raw.PX_LAST

# %%
df_spx_close.tail()
# Out:
# Date
# 2000-01-07    1441.47
# 2000-01-06    1403.45
# 2000-01-05    1402.11
# 2000-01-04    1399.42
# 2000-01-03    1455.22
# Name: PX_LAST, dtype: float64

# %%
df_spx_rtn=df_spx_close.pct_change()

# %%
df_spx_rtn.tail()
# Out:
# Date
# 2000-01-07   -0.011066
# 2000-01-06   -0.026376
# 2000-01-05   -0.000955
# 2000-01-04   -0.001919
# 2000-01-03    0.039874
# Name: PX_LAST, dtype: float64

# %%
df_bcom_rtn=df_bcom_close.pct_change()

# %%
df_bcom_rtn.tail()
# Out:
# Date
# 2000-01-07   -0.002643
# 2000-01-06    0.003201
# 2000-01-05   -0.000414
# 2000-01-04    0.005416
# 2000-01-03    0.006010
# Name: PX_LAST, dtype: float64

# %%
df_bcom_rtn.head()
# Out:
# Date
# 2019-02-25         NaN
# 2019-02-22    0.010130
# 2019-02-21   -0.004101
# 2019-02-20   -0.001292
# 2019-02-19   -0.004749
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4802

# %%
plot(rtn_df.bcom_rtn, rtn_df.spx_rtn, 'b.')
plt.title('title')
plt.xlabel("bcom_close")
plt.ylabel("spx_close")
# Out:
# Text(0, 0.5, 'spx_close')

# %%
rtn_df.corr()
# Out:
#            spx_rtn  bcom_rtn
# spx_rtn   1.000000  0.245991
# bcom_rtn  0.245991  1.000000

# %%
rtn_df
# Out:
#              spx_rtn  bcom_rtn
# Date
# 2000-01-03  0.039874  0.006010
# 2000-01-04 -0.001919  0.005416
# 2000-01-05 -0.000955 -0.000414
# 2000-01-06 -0.026376  0.003201
# 2000-01-07 -0.011066 -0.002643
# 2000-01-10  0.013235 -0.011494
# 2000-01-11  0.004406 -0.011942
# 2000-01-12 -0.012023 -0.006799
# 2000-01-13 -0.010559 -0.014852
# 2000-01-14  0.006879 -0.012810
# 2000-01-18 -0.000522 -0.007580
# 2000-01-19  0.007146 -0.004768
# 2000-01-20  0.002921  0.001884
# 2000-01-21  0.028419  0.004310
# 2000-01-24 -0.006028 -0.005970
# 2000-01-25  0.004230  0.008117
# 2000-01-26  0.003954 -0.001123
# 2000-01-27  0.028232  0.004562
# 2000-01-28 -0.024597 -0.003112
# 2000-01-31 -0.010516 -0.007529
# 2000-02-01  0.000114  0.007799
# 2000-02-02 -0.011123 -0.003493
# 2000-02-03  0.000421 -0.018525
# 2000-02-04  0.000091  0.013240
# 2000-02-07 -0.012124  0.012887
# 2000-02-08  0.021265 -0.012522
# 2000-02-09 -0.003621 -0.016731
# 2000-02-10  0.021418  0.005254
# 2000-02-11 -0.002029 -0.001015
# 2000-02-14 -0.008637  0.004418
# ...              ...       ...
# 2019-01-10  0.000146 -0.002164
# 2019-01-11  0.005285 -0.003012
# 2019-01-14 -0.010608 -0.002524
# 2019-01-15 -0.002217 -0.001930
# 2019-01-16 -0.007534 -0.002374
# 2019-01-17 -0.013012 -0.011414
# 2019-01-18  0.014361  0.016107
# 2019-01-22 -0.002198  0.000177
# 2019-01-23 -0.001374 -0.001679
# 2019-01-24 -0.008417 -0.010605
# 2019-01-25  0.007909  0.015053
# 2019-01-28  0.001458 -0.007867
# 2019-01-29 -0.015311 -0.004720
# 2019-01-30 -0.008524  0.001945
# 2019-01-31 -0.000898 -0.002962
# 2019-02-01 -0.006731 -0.001670
# 2019-02-04 -0.004686  0.002718
# 2019-02-05  0.002229 -0.001297
# 2019-02-06  0.009446  0.011825
# 2019-02-07 -0.000676 -0.000330
# 2019-02-08 -0.000709  0.005147
# 2019-02-11 -0.012726 -0.005516
# 2019-02-12 -0.003015 -0.000833
# 2019-02-13  0.002659  0.002539
# 2019-02-14 -0.010762 -0.012300
# 2019-02-15 -0.001497 -0.004149
# 2019-02-19 -0.001774 -0.004749
# 2019-02-20  0.003539 -0.001292
# 2019-02-21 -0.006370 -0.004101
# 2019-02-22 -0.001230  0.010130
#
# [4802 rows x 2 columns]

# %%
df_copper_raw = pd.read_excel('Copper Futures.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_copper_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-10    84.65     NaN       NaN    84.50       NaN         NaN     85.9
# 2000-01-07    85.40     NaN       NaN    86.15       NaN         NaN     86.2
# 2000-01-06    85.30     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-05    85.65     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-04    84.80     NaN       NaN      NaN       NaN         NaN      NaN
#
#             Change.2  % Change.2  PX_LOW  Change.3  % Change.3
# Date
# 2000-01-10       NaN         NaN    84.8       NaN         NaN
# 2000-01-07       NaN         NaN    83.8       NaN         NaN
# 2000-01-06       NaN         NaN    84.5       NaN         NaN
# 2000-01-05       NaN         NaN     NaN       NaN         NaN
# 2000-01-04       NaN         NaN     NaN       NaN         NaN

# %%
df_copper_close = df_copper_raw.PX_LAST

# %%
df_copper_close.tail()
# Out:
# Date
# 2000-01-10    84.65
# 2000-01-07    85.40
# 2000-01-06    85.30
# 2000-01-05    85.65
# 2000-01-04    84.80
# Name: PX_LAST, dtype: float64

# %%
df_copper_rtn=df_copper_close.pct_change()

# %%
df_copper_rtn.tail()
# Out:
# Date
# 2000-01-10    0.003557
# 2000-01-07    0.008860
# 2000-01-06   -0.001171
# 2000-01-05    0.004103
# 2000-01-04   -0.009924
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn, 'copper_rtn':df_copper_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4801

# %%
rtn_df.tail()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn
# Date
# 2019-02-15 -0.001497 -0.004149   -0.026439
# 2019-02-19 -0.001774 -0.004749   -0.015582
# 2019-02-20  0.003539 -0.001292    0.007939
# 2019-02-21 -0.006370 -0.004101   -0.018465
# 2019-02-22 -0.001230  0.010130    0.002207

# %%
rtn_df.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn
# spx_rtn     1.000000  0.245881    0.273894
# bcom_rtn    0.245881  1.000000    0.579534
# copper_rtn  0.273894  0.579534    1.000000

# %%
plot(rtn_df.copper_rtn, rtn_df.spx_rtn, 'b.')
plt.title('title')
plt.xlabel("bcom_close")
plt.ylabel("spx_close")
# Out:
# Text(0, 0.5, 'spx_close')

# %%
df_oil_raw = pd.read_excel('Crude Oil Futures.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_oil_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-10    24.67     NaN       NaN    24.15       NaN         NaN    24.75
# 2000-01-07    24.22     NaN       NaN    24.65       NaN         NaN    25.00
# 2000-01-06    24.78     NaN       NaN    24.80       NaN         NaN    25.34
# 2000-01-05    24.91     NaN       NaN    25.50       NaN         NaN    25.61
# 2000-01-04    25.55     NaN       NaN    25.20       NaN         NaN    25.69
#
#             Change.2  % Change.2  PX_LOW  Change.3  % Change.3
# Date
# 2000-01-10       NaN         NaN   24.02       NaN         NaN
# 2000-01-07       NaN         NaN   24.15       NaN         NaN
# 2000-01-06       NaN         NaN   24.51       NaN         NaN
# 2000-01-05       NaN         NaN   24.86       NaN         NaN
# 2000-01-04       NaN         NaN   24.71       NaN         NaN

# %%
df_oil_close = df_oil_raw.PX_LAST

# %%
df_oil_close.tail()
# Out:
# Date
# 2000-01-10    24.67
# 2000-01-07    24.22
# 2000-01-06    24.78
# 2000-01-05    24.91
# 2000-01-04    25.55
# Name: PX_LAST, dtype: float64

# %%
df_oil_rtn = df_oil_close.pct_change()

# %%
df_oil_rtn.tail()
# Out:
# Date
# 2000-01-10   -0.042685
# 2000-01-07   -0.018241
# 2000-01-06    0.023121
# 2000-01-05    0.005246
# 2000-01-04    0.025692
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn, 'copper_rtn':df_copper_rtn, 'oil_rtn':df_oil_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4801

# %%
rtn_df.corr() #sp vs copper and oil, more explanatory power? Do different time periods? Copper and oil related to economy that in boom, both go up. Tell a story. What does copper say about economy thats different from oil. Look at gold.
#Economic indicators, gpd, industrial production?
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn
# spx_rtn     1.000000  0.245881    0.273894  0.207886
# bcom_rtn    0.245881  1.000000    0.579534  0.740862
# copper_rtn  0.273894  0.579534    1.000000  0.315308
# oil_rtn     0.207886  0.740862    0.315308  1.000000

# %%
rtn_df.head(50)
#Lead or lag effects? Equities lead copper? Economic cycles into boom and bust. Show Equity returns. Commodity returns
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn
# 2019-02-15 -0.001497 -0.004149   -0.026439 -0.008914
# 2019-02-19 -0.001774 -0.004749   -0.015582 -0.014582
# 2019-02-20  0.003539 -0.001292    0.007939 -0.000702
# 2019-02-21 -0.006370 -0.004101   -0.018465 -0.005239
# 2019-02-22 -0.001230  0.010130    0.002207  0.032084

# %%
df_gold_raw = pd.read_excel('Gold Futures Prices.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_gold_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-10    282.7     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-07    282.9     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-06    282.4     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-05    282.1     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-04    283.7     NaN       NaN      NaN       NaN         NaN      NaN
#
#             Change.2  % Change.2  PX_LOW  Change.3  % Change.3
# Date
# 2000-01-10       NaN         NaN     NaN       NaN         NaN
# 2000-01-07       NaN         NaN     NaN       NaN         NaN
# 2000-01-06       NaN         NaN     NaN       NaN         NaN
# 2000-01-05       NaN         NaN     NaN       NaN         NaN
# 2000-01-04       NaN         NaN     NaN       NaN         NaN

# %%
df_gold_close = df_gold_raw.PX_LAST

# %%
df_gold_close.tail()
# Out:
# Date
# 2000-01-10    282.7
# 2000-01-07    282.9
# 2000-01-06    282.4
# 2000-01-05    282.1
# 2000-01-04    283.7
# Name: PX_LAST, dtype: float64

# %%
df_gold_rtn=df_gold_close.pct_change()

# %%
df_gold_rtn.tail()
# Out:
# Date
# 2000-01-10   -0.005977
# 2000-01-07    0.000707
# 2000-01-06   -0.001767
# 2000-01-05   -0.001062
# 2000-01-04    0.005672
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn, 'copper_rtn':df_copper_rtn, 'oil_rtn':df_oil_rtn, 'gold_rtn':df_gold_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4801

# %%
rtn_df.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000  0.245881    0.273894  0.207886 -0.029275
# bcom_rtn    0.245881  1.000000    0.579534  0.740862  0.431936
# copper_rtn  0.273894  0.579534    1.000000  0.315308  0.327974
# oil_rtn     0.207886  0.740862    0.315308  1.000000  0.211366
# gold_rtn   -0.029275  0.431936    0.327974  0.211366  1.000000

# %%
x = rtn_df.bcom_rtn
y = rtn_df.spx_rtn
X = np.ones((x.size, 2))
X[:,1] = x

# %%
beta_Hat = dot(dot(inv(dot(X.T, X)) , X.T), y)
y_Hat = dot(X, beta_Hat)

# %%
plot(x,y,'b.')
plot(x,y_Hat,'r.')
plt.title('title')
plt.xlabel("bcom_rtn")
plt.ylabel("spx_rtn")
# Out:
# Text(0, 0.5, 'spx_rtn')
