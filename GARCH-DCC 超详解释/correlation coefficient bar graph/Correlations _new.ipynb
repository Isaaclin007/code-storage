# %%
import pandas as pd 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_bcom_raw = pd.read_excel('BCOM Index (OHLC).xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_bcom_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-07  90.7495     NaN       NaN  90.7495       NaN         NaN  90.7495
# 2000-01-06  91.0400     NaN       NaN  91.0400       NaN         NaN  91.0400
# 2000-01-05  91.0023     NaN       NaN  91.0023       NaN         NaN  91.0023
# 2000-01-04  91.4952     NaN       NaN  91.4952       NaN         NaN  91.4952
# 2000-01-03  92.0451     NaN       NaN  92.0451       NaN         NaN  92.0451
#
#             Change.2  % Change.2   PX_LOW  Change.3  % Change.3
# Date
# 2000-01-07       NaN         NaN  90.7495       NaN         NaN
# 2000-01-06       NaN         NaN  91.0400       NaN         NaN
# 2000-01-05       NaN         NaN  91.0023       NaN         NaN
# 2000-01-04       NaN         NaN  91.4952       NaN         NaN
# 2000-01-03       NaN         NaN  92.0451       NaN         NaN

# %%
df_spx_raw = pd.read_excel('SPX Index (OHLC).xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
len(df_spx_raw)
df_spx_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-07  1441.47     NaN       NaN  1403.45       NaN         NaN  1441.47
# 2000-01-06  1403.45     NaN       NaN  1402.11       NaN         NaN  1411.90
# 2000-01-05  1402.11     NaN       NaN  1399.42       NaN         NaN  1413.27
# 2000-01-04  1399.42     NaN       NaN  1455.22       NaN         NaN  1455.22
# 2000-01-03  1455.22     NaN       NaN  1469.25       NaN         NaN  1478.00
#
#             Change.2  % Change.2   PX_LOW  Change.3  % Change.3
# Date
# 2000-01-07       NaN         NaN  1400.73       NaN         NaN
# 2000-01-06       NaN         NaN  1392.02       NaN         NaN
# 2000-01-05       NaN         NaN  1377.68       NaN         NaN
# 2000-01-04       NaN         NaN  1397.43       NaN         NaN
# 2000-01-03       NaN         NaN  1438.36       NaN         NaN

# %%
df_bcom_close = df_bcom_raw.PX_LAST
df_bcom_close = df_bcom_close.sort_index(ascending=True)

# %%
df_bcom_close.head()
# Out:
# Date
# 2000-01-03    92.0451
# 2000-01-04    91.4952
# 2000-01-05    91.0023
# 2000-01-06    91.0400
# 2000-01-07    90.7495
# Name: PX_LAST, dtype: float64

# %%
df_bcom_close.tail()
# Out:
# Date
# 2019-02-19    81.2942
# 2019-02-20    81.6821
# 2019-02-21    81.7878
# 2019-02-22    82.1246
# 2019-02-25    81.3010
# Name: PX_LAST, dtype: float64

# %%
df_spx_close = df_spx_raw.PX_LAST
df_spx_close = df_spx_close.sort_index(ascending=True)

# %%
df_spx_close.head()
# Out:
# Date
# 2000-01-03    1455.22
# 2000-01-04    1399.42
# 2000-01-05    1402.11
# 2000-01-06    1403.45
# 2000-01-07    1441.47
# Name: PX_LAST, dtype: float64

# %%
df_spx_close.tail()
# Out:
# Date
# 2019-02-19    2779.76
# 2019-02-20    2784.70
# 2019-02-21    2774.88
# 2019-02-22    2792.67
# 2019-02-25    2796.11
# Name: PX_LAST, dtype: float64

# %%
df_spx_rtn=df_spx_close.pct_change()

# %%
df_spx_rtn.tail()
# Out:
# Date
# 2019-02-19    0.001499
# 2019-02-20    0.001777
# 2019-02-21   -0.003526
# 2019-02-22    0.006411
# 2019-02-25    0.001232
# Name: PX_LAST, dtype: float64

# %%
df_bcom_rtn=df_bcom_close.pct_change()

# %%
df_bcom_rtn.tail()
# Out:
# Date
# 2019-02-19    0.004166
# 2019-02-20    0.004772
# 2019-02-21    0.001294
# 2019-02-22    0.004118
# 2019-02-25   -0.010029
# Name: PX_LAST, dtype: float64

# %%
df_bcom_rtn.head()
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.005974
# 2000-01-05   -0.005387
# 2000-01-06    0.000414
# 2000-01-07   -0.003191
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4802

# %%
plot(rtn_df.bcom_rtn, rtn_df.spx_rtn, 'b.')
plt.title('title')
plt.xlabel("bcom_close")
plt.ylabel("spx_close")
# Out:
# Text(0, 0.5, 'spx_close')

# %%
rtn_df.corr()
# Out:
#            spx_rtn  bcom_rtn
# spx_rtn   1.000000  0.245507
# bcom_rtn  0.245507  1.000000

# %%
df_copper_raw = pd.read_excel('Copper Futures.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_copper_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-10    84.65     NaN       NaN    84.50       NaN         NaN     85.9
# 2000-01-07    85.40     NaN       NaN    86.15       NaN         NaN     86.2
# 2000-01-06    85.30     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-05    85.65     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-04    84.80     NaN       NaN      NaN       NaN         NaN      NaN
#
#             Change.2  % Change.2  PX_LOW  Change.3  % Change.3
# Date
# 2000-01-10       NaN         NaN    84.8       NaN         NaN
# 2000-01-07       NaN         NaN    83.8       NaN         NaN
# 2000-01-06       NaN         NaN    84.5       NaN         NaN
# 2000-01-05       NaN         NaN     NaN       NaN         NaN
# 2000-01-04       NaN         NaN     NaN       NaN         NaN

# %%
df_copper_close = df_copper_raw.PX_LAST
df_copper_close = df_copper_close.sort_index(ascending=True)

# %%
df_copper_close.tail()
# Out:
# Date
# 2019-03-01    293.35
# 2019-03-04    291.10
# 2019-03-05    293.60
# 2019-03-06    291.85
# 2019-03-07    291.15
# Name: PX_LAST, dtype: float64

# %%
df_copper_rtn=df_copper_close.pct_change()

# %%
df_copper_rtn.tail()
# Out:
# Date
# 2019-03-01   -0.005593
# 2019-03-04   -0.007670
# 2019-03-05    0.008588
# 2019-03-06   -0.005960
# 2019-03-07   -0.002398
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn, 'copper_rtn':df_copper_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# C:\Users\Alexander\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:2792: FutureWarning: In the future, 'NAT < x' and 'x < NAT' will always be False.
#   lvals[0] < other_diff[0]
# 4800

# %%
rtn_df.tail()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn
# Date
# 2019-02-15  0.010879  0.012454    0.008832
# 2019-02-19  0.001499  0.004166    0.027157
# 2019-02-20  0.001777  0.004772    0.015829
# 2019-02-21 -0.003526  0.001294   -0.007877
# 2019-02-22  0.006411  0.004118    0.018813

# %%
rtn_df.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn
# spx_rtn     1.000000  0.245429    0.272632
# bcom_rtn    0.245429  1.000000    0.580887
# copper_rtn  0.272632  0.580887    1.000000

# %%
plot(rtn_df.copper_rtn, rtn_df.spx_rtn, 'b.')
plt.title('title')
plt.xlabel("bcom_close")
plt.ylabel("spx_close")
# Out:
# Text(0, 0.5, 'spx_close')

# %%
df_oil_raw = pd.read_excel('Crude Oil Futures.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_oil_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-10    24.67     NaN       NaN    24.15       NaN         NaN    24.75
# 2000-01-07    24.22     NaN       NaN    24.65       NaN         NaN    25.00
# 2000-01-06    24.78     NaN       NaN    24.80       NaN         NaN    25.34
# 2000-01-05    24.91     NaN       NaN    25.50       NaN         NaN    25.61
# 2000-01-04    25.55     NaN       NaN    25.20       NaN         NaN    25.69
#
#             Change.2  % Change.2  PX_LOW  Change.3  % Change.3
# Date
# 2000-01-10       NaN         NaN   24.02       NaN         NaN
# 2000-01-07       NaN         NaN   24.15       NaN         NaN
# 2000-01-06       NaN         NaN   24.51       NaN         NaN
# 2000-01-05       NaN         NaN   24.86       NaN         NaN
# 2000-01-04       NaN         NaN   24.71       NaN         NaN

# %%
df_oil_close = df_oil_raw.PX_LAST
df_oil_close = df_oil_close.sort_index(ascending=True)

# %%
df_oil_close.tail()
# Out:
# Date
# 2019-03-01    55.80
# 2019-03-04    56.59
# 2019-03-05    56.56
# 2019-03-06    56.22
# 2019-03-07    56.66
# Name: PX_LAST, dtype: float64

# %%
df_oil_rtn = df_oil_close.pct_change()

# %%
df_oil_rtn.tail()
# Out:
# Date
# 2019-03-01   -0.024816
# 2019-03-04    0.014158
# 2019-03-05   -0.000530
# 2019-03-06   -0.006011
# 2019-03-07    0.007826
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn, 'copper_rtn':df_copper_rtn, 'oil_rtn':df_oil_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4800

# %%
rtn_df.corr() #sp vs copper and oil, more explanatory power? Do different time periods? Copper and oil related to economy that in boom, both go up. Tell a story. What does copper say about economy thats different from oil. Look at gold.
#Economic indicators, gpd, industrial production?
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn
# spx_rtn     1.000000  0.245429    0.272632  0.206323
# bcom_rtn    0.245429  1.000000    0.580887  0.739830
# copper_rtn  0.272632  0.580887    1.000000  0.315139
# oil_rtn     0.206323  0.739830    0.315139  1.000000

# %%
rtn_df.head(50)
#Lead or lag effects? Equities lead copper? Economic cycles into boom and bust. Show Equity returns. Commodity returns
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn
# Date
# 2000-01-05  0.001922 -0.005387    0.010024 -0.025049
# 2000-01-06  0.000956  0.000414   -0.004086 -0.005219
# 2000-01-07  0.027090 -0.003191    0.001172 -0.022599
# 2000-01-10  0.011190  0.002650   -0.008782  0.018580
# 2000-01-11 -0.013063  0.011628   -0.003544  0.044589
# 2000-01-12 -0.004386  0.012086    0.026675  0.019790
# 2000-01-13  0.012170  0.006845   -0.010970  0.015601
# 2000-01-14  0.010671  0.015076    0.007005  0.049831
# 2000-01-18 -0.006832  0.012976    0.004058  0.029622
# 2000-01-19  0.000522  0.007638    0.019053  0.023917
# 2000-01-20 -0.007095  0.004791   -0.010765  0.004062
# 2000-01-21 -0.002912 -0.001880    0.000000 -0.049225
# 2000-01-24 -0.027634 -0.004292   -0.018900 -0.013121
# 2000-01-25  0.006065  0.006006   -0.016346  0.016170
# 2000-01-26 -0.004213 -0.008052   -0.001187 -0.015559
# 2000-01-27 -0.003938  0.001124    0.003565 -0.018678
# 2000-01-28 -0.027457 -0.004541   -0.011249 -0.003660
# ...

# %%
rtn_df.tail(50)
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn
# Date
# 2018-12-11 -0.000356 -0.001307    0.017473  0.012745
# 2018-12-12  0.005419 -0.005279    0.000904 -0.009681
# 2018-12-13 -0.000200  0.004004   -0.002167  0.027957
# 2018-12-14 -0.019087 -0.015134   -0.000724 -0.026246
# 2018-12-17 -0.020773 -0.012315   -0.002717 -0.025781
# 2018-12-18  0.000086 -0.007290   -0.029786 -0.072975
# 2018-12-19 -0.015396  0.003474    0.018907  0.020761
# 2018-12-20 -0.015772 -0.014349   -0.007165 -0.027966
# 2018-12-21 -0.020588 -0.001447   -0.008697 -0.006321
# 2018-12-24 -0.027112 -0.018839   -0.003733 -0.067120
# 2018-12-26  0.049594  0.012973    0.014990  0.086762
# 2018-12-27  0.008563 -0.005261   -0.015138 -0.034833
# 2018-12-28 -0.001242 -0.002708    0.005248  0.016140
# 2018-12-31  0.008492 -0.011300   -0.018833  0.001765
# 2019-01-02  0.001269  0.003516   -0.003041  0.024884
# 2019-01-03 -0.024757  0.006096   -0.020968  0.011818
# 2019-01-04  0.034336  0.011372    0.030958  0.018475
# ...

# %%
df_gold_raw = pd.read_excel('Gold Futures Prices.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_gold_raw.tail()
# Out:
#             PX_LAST  Change  % Change  PX_OPEN  Change.1  % Change.1  PX_HIGH  \
# Date
# 2000-01-10    282.7     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-07    282.9     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-06    282.4     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-05    282.1     NaN       NaN      NaN       NaN         NaN      NaN
# 2000-01-04    283.7     NaN       NaN      NaN       NaN         NaN      NaN
#
#             Change.2  % Change.2  PX_LOW  Change.3  % Change.3
# Date
# 2000-01-10       NaN         NaN     NaN       NaN         NaN
# 2000-01-07       NaN         NaN     NaN       NaN         NaN
# 2000-01-06       NaN         NaN     NaN       NaN         NaN
# 2000-01-05       NaN         NaN     NaN       NaN         NaN
# 2000-01-04       NaN         NaN     NaN       NaN         NaN

# %%
df_gold_close = df_gold_raw.PX_LAST
df_gold_close = df_gold_close.sort_index(ascending=True)

# %%
df_gold_close.tail()
# Out:
# Date
# 2019-03-01    1299.2
# 2019-03-04    1287.5
# 2019-03-05    1284.7
# 2019-03-06    1287.6
# 2019-03-07    1286.1
# Name: PX_LAST, dtype: float64

# %%
df_gold_rtn=df_gold_close.pct_change()

# %%
df_gold_rtn.tail()
# Out:
# Date
# 2019-03-01   -0.012841
# 2019-03-04   -0.009006
# 2019-03-05   -0.002175
# 2019-03-06    0.002257
# 2019-03-07   -0.001165
# Name: PX_LAST, dtype: float64

# %%
rtn_df = pd.DataFrame({'spx_rtn':df_spx_rtn, 'bcom_rtn':df_bcom_rtn, 'copper_rtn':df_copper_rtn, 'oil_rtn':df_oil_rtn, 'gold_rtn':df_gold_rtn})
rtn_df.dropna(inplace=True)
len(rtn_df)
# Out:
# 4800

# %%
rtn_df.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000  0.245429    0.272632  0.206323 -0.030414
# bcom_rtn    0.245429  1.000000    0.580887  0.739830  0.431674
# copper_rtn  0.272632  0.580887    1.000000  0.315139  0.326715
# oil_rtn     0.206323  0.739830    0.315139  1.000000  0.213091
# gold_rtn   -0.030414  0.431674    0.326715  0.213091  1.000000

# %%
x = rtn_df.bcom_rtn
y = rtn_df.spx_rtn
X = np.ones((x.size, 2))
X[:,1] = x

# %%
beta_Hat = dot(dot(inv(dot(X.T, X)) , X.T), y)
y_Hat = dot(X, beta_Hat)

# %%
plot(x,y,'b.')
plot(x,y_Hat,'r.')
plt.title('title')
plt.xlabel("bcom_rtn")
plt.ylabel("spx_rtn")
# Out:
# Text(0, 0.5, 'spx_rtn')

# %%
rtn_df.head()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# Date
# 2000-01-05  0.001922 -0.005387    0.010024 -0.025049 -0.005640
# 2000-01-06  0.000956  0.000414   -0.004086 -0.005219  0.001063
# 2000-01-07  0.027090 -0.003191    0.001172 -0.022599  0.001771
# 2000-01-10  0.011190  0.002650   -0.008782  0.018580 -0.000707
# 2000-01-11 -0.013063  0.011628   -0.003544  0.044589  0.006013

# %%
rtn_df1 = rtn_df.loc['2000-1-4':'2001-1-31']

# %%
rtn_df1.head()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# Date
# 2000-01-05  0.001922 -0.005387    0.010024 -0.025049 -0.005640
# 2000-01-06  0.000956  0.000414   -0.004086 -0.005219  0.001063
# 2000-01-07  0.027090 -0.003191    0.001172 -0.022599  0.001771
# 2000-01-10  0.011190  0.002650   -0.008782  0.018580 -0.000707
# 2000-01-11 -0.013063  0.011628   -0.003544  0.044589  0.006013

# %%
rtn_df1.tail()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# Date
# 2001-01-25 -0.004977  0.001804    0.002395  0.010671  0.000756
# 2001-01-26 -0.001886  0.001824    0.003584  0.013965 -0.007175
# 2001-01-29  0.006805 -0.016693   -0.008929 -0.023850 -0.000380
# 2001-01-30  0.007008  0.001764    0.010210  0.000000  0.010274
# 2001-01-31 -0.005620 -0.008820    0.005351 -0.013765  0.000377

# %%
rtn_df1.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000 -0.058367    0.250607 -0.055984 -0.041103
# bcom_rtn   -0.058367  1.000000    0.115334  0.678354  0.303455
# copper_rtn  0.250607  0.115334    1.000000 -0.137232  0.090606
# oil_rtn    -0.055984  0.678354   -0.137232  1.000000  0.080423
# gold_rtn   -0.041103  0.303455    0.090606  0.080423  1.000000

# %%
rtn_df2 = rtn_df.loc['2001-2-1':'2002-1-31']

# %%
rtn_df2.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000 -0.005942    0.195921 -0.019382 -0.111438
# bcom_rtn   -0.005942  1.000000    0.342862  0.786852  0.294577
# copper_rtn  0.195921  0.342862    1.000000  0.093232  0.091427
# oil_rtn    -0.019382  0.786852    0.093232  1.000000  0.134400
# gold_rtn   -0.111438  0.294577    0.091427  0.134400  1.000000

# %%
rtn_df3 = rtn_df.loc['2002-2-1':'2007-12-31']

# %%
rtn_df3.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000  0.060858    0.168733 -0.025900 -0.068771
# bcom_rtn    0.060858  1.000000    0.463637  0.733771  0.448907
# copper_rtn  0.168733  0.463637    1.000000  0.153729  0.375596
# oil_rtn    -0.025900  0.733771    0.153729  1.000000  0.236069
# gold_rtn   -0.068771  0.448907    0.375596  0.236069  1.000000

# %%
rtn_df4 = rtn_df.loc['2008-1-1':'2009-6-30']

# %%
rtn_df4.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000  0.343425    0.288982  0.307961 -0.065943
# bcom_rtn    0.343425  1.000000    0.756384  0.774704  0.446410
# copper_rtn  0.288982  0.756384    1.000000  0.532543  0.322109
# oil_rtn     0.307961  0.774704    0.532543  1.000000  0.295453
# gold_rtn   -0.065943  0.446410    0.322109  0.295453  1.000000

# %%
rtn_df5 = rtn_df.loc['2009-7-1':'2019-2-22']

# %%
rtn_df5.corr()
# Out:
#              spx_rtn  bcom_rtn  copper_rtn   oil_rtn  gold_rtn
# spx_rtn     1.000000  0.387814    0.373131  0.381773  0.031308
# bcom_rtn    0.387814  1.000000    0.630876  0.737488  0.436347
# copper_rtn  0.373131  0.630876    1.000000  0.393151  0.328491
# oil_rtn     0.381773  0.737488    0.393151  1.000000  0.182390
# gold_rtn    0.031308  0.436347    0.328491  0.182390  1.000000

# %%
df_bcomm_raw = pd.read_excel('BCOM Index Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_copperm_raw = pd.read_excel('Copper Futures Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_oilm_raw = pd.read_excel('Crude Oil Futures Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_goldm_raw = pd.read_excel('Gold Futures Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_Europe_raw = pd.read_excel('MSCI Europe Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_Latin_raw = pd.read_excel('MSCI Latin America Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_RTYm_raw = pd.read_excel('RTY Index Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_SPXm_raw = pd.read_excel('SPX Index Monthly.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)

# %%
df_bcomm_close = df_bcomm_raw.PX_LAST
df_bcomm_close = df_bcomm_close.sort_index(ascending=True)

# %%
df_copperm_close = df_copperm_raw.PX_LAST
df_copperm_close = df_copperm_close.sort_index(ascending=True)

# %%
df_oilm_close = df_oilm_raw.PX_LAST
df_oilm_close = df_oilm_close.sort_index(ascending=True)

# %%
df_goldm_close = df_goldm_raw.PX_LAST
df_goldm_close = df_goldm_close.sort_index(ascending=True)

# %%
df_Europe_close = df_Europe_raw.PX_LAST
df_Europe_close = df_Europe_close.sort_index(ascending=True)

# %%
df_Latin_close = df_Latin_raw.PX_LAST
df_Latin_close = df_Latin_close.sort_index(ascending=True)

# %%
df_RTYm_close = df_RTYm_raw.PX_LAST
df_RTYm_close = df_RTYm_close.sort_index(ascending=True)

# %%
df_SPXm_close = df_SPXm_raw.PX_LAST
df_SPXm_close = df_SPXm_close.sort_index(ascending=True)

# %%
df_bcomm_rtn = df_bcomm_close.pct_change()
df_copperm_rtn = df_copperm_close.pct_change()
df_oilm_rtn = df_oilm_close.pct_change()
df_goldm_rtn = df_goldm_close.pct_change()
df_Europe_rtn = df_Europe_close.pct_change()
df_Latin_rtn = df_Latin_close.pct_change()
df_RTYm_rtn = df_RTYm_close.pct_change()
df_SPXm_rtn = df_SPXm_close.pct_change()

# %%
rtnm_df = pd.DataFrame({'SPXm_rtn':df_SPXm_rtn, 'BCOMm_rtn':df_bcomm_rtn, 'copperm_rtn':df_copperm_rtn, 'oilm_rtn':df_oilm_rtn, 'goldm_rtn':df_goldm_rtn, 'Europe_rtn':df_Europe_rtn, 'Latin_rtn':df_Latin_rtn, 'RTYm_rtn' :df_RTYm_rtn})
rtnm_df.dropna(inplace=True)

# %%
rtnm_df.corr()
# Out:
#              SPXm_rtn  BCOMm_rtn  copperm_rtn  oilm_rtn  goldm_rtn  \
# SPXm_rtn     1.000000   0.374440     0.440817  0.265681   0.010904
# BCOMm_rtn    0.374440   1.000000     0.603929  0.732297   0.454125
# copperm_rtn  0.440817   0.603929     1.000000  0.387268   0.281996
# oilm_rtn     0.265681   0.732297     0.387268  1.000000   0.218952
# goldm_rtn    0.010904   0.454125     0.281996  0.218952   1.000000
# Europe_rtn   0.830566   0.264743     0.327627  0.218164  -0.076362
# Latin_rtn    0.671430   0.507494     0.462567  0.381059   0.329798
# RTYm_rtn     0.831820   0.344892     0.375914  0.298622   0.061277
#
#              Europe_rtn  Latin_rtn  RTYm_rtn
# SPXm_rtn       0.830566   0.671430  0.831820
# BCOMm_rtn      0.264743   0.507494  0.344892
# copperm_rtn    0.327627   0.462567  0.375914
# oilm_rtn       0.218164   0.381059  0.298622
# goldm_rtn     -0.076362   0.329798  0.061277
# Europe_rtn     1.000000   0.620253  0.733708
# ...
