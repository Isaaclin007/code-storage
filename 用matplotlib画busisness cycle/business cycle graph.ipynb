# %%
import pandas as pd 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_bcom_raw = pd.read_excel('bcom index since 1969.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_bcom_close = df_bcom_raw.PX_LAST
df_bcom_close = df_bcom_close.sort_index(ascending=True)

# %%
df_spx_raw = pd.read_excel('spx index since1969.xlsx', skiprows=[0,1,2,3,4,5], parse_dates=['Date'], index_col=0)
df_spx_close = df_spx_raw.PX_LAST
df_spx_close = df_spx_close.sort_index(ascending=True)

# %%
close_df = pd.DataFrame({'spx':df_spx_close, 'bcom':df_bcom_close})

# %%
close_df.head()
# Out:
#               spx     bcom
# Date
# 1969-12-04  91.95  16.1145
# 1969-12-05  91.73  16.1675
# 1969-12-08  90.63  16.1626
# 1969-12-09  90.55  16.0815
# 1969-12-10  90.48  16.0250

# %%
res = close_df.pct_change(periods=252)*100

# %%
len(close_df['2004'])
# Out:
# 252

# %%
fig = plt.figure(figsize=(100,20))


font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 65}
plt.grid(True) #画格子线
plt.ylabel('Percent Change from Year Ago',font1)
plt.tick_params(labelsize=60) #X轴下面的数字大小
plt.plot(res)
plt.legend(('spx', 'bcom'),shadow=True, loc=(0.91, 0.8), handlelength=1.5, fontsize=50)

# 画阴影部分
recession_list = [('2008', '2009-6'),('2001-4', '2001-11'),('1990-8','1991-4'),('1981-8','1983-2'),('1980-2','1980-6'),('1973-12','1975-4'),('1970-1','1970-12')]

for begin,end in recession_list:
    plt.axvspan(begin, end, facecolor='#89a0b0', alpha=0.5)

# %%
fig = plt.figure(figsize=(100,20))

plt.plot(res['1999':])
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 65}
plt.grid(True) #画格子线
plt.ylabel('Percent Change from Year Ago',font1)
plt.tick_params(labelsize=60)

plt.legend(('spx', 'bcom'),shadow=True, loc=(0.91, 0.8), handlelength=1.5, fontsize=50)

# 画阴影部分
recession_list = [('2008', '2009-6'),('2001-4', '2001-11'),('1990-8','1991-4'),('1981-8','1983-2'),('1980-2','1980-6'),('1973-12','1975-4'),('1970-1','1970-12')]

for begin,end in recession_list[:2]:
    plt.axvspan(begin, end, facecolor='#89a0b0', alpha=0.5)
