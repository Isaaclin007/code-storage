# %% [markdown]
# Before running a script to get stock twits, let's see how the api works.
# To get the stock twits for a specific ticker, we put together a url as in this
# example:
#
# https://api.stocktwits.com/api/2/streams/symbol/SPX.json
#
# The response is a json string which we can convert to a Python object directly using the following.

# %%
import requests
import json

url="https://api.stocktwits.com/api/2/streams/symbol/SPX.json"
req=requests.get(url)
obj=req.json()

# %% [markdown]
# Now we try to unravel what type of object we have and how we can get information we want from it.

# %%
print(type(obj))
# Out:
# <class 'dict'>

# %%
print(obj.keys())
# Out:
# dict_keys(['response', 'symbol', 'cursor', 'messages'])

# %%
print(obj['response'])
# Out:
# {'status': 200}

# %%
print(obj['symbol'])
# Out:
# {'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}

# %% [markdown]
# Just want the symbol from this.

# %%
print(obj['cursor'])
# Out:
# {'more': True, 'since': 151303163, 'max': 151298843}

# %% [markdown]
# Don't want to keep this.

# %%
print(obj['messages'][0])
# Out:
# {'id': 151303163, 'body': '$SPY LEVELS FOR TODAY \n \nhttp://www.tradewithjoe.com/market-maker-moves-for-w-e-1-25-2019/ \n \n$SPX $IWM $RUT $NDX $QQQ $DIA $FB $AMZN $NFLX $GOOGL $BABA $BIDU $NVDA $AAPL $TSLA $BKNG', 'created_at': '2019-01-22T14:14:35Z', 'user': {'id': 234409, 'username': 'tradewithjoe', 'name': 'Lloyd Cox', 'avatar_url': 'https://avatars.stocktwits.com/production/234409/thumb-1457903288.png', 'avatar_url_ssl': 'https://avatars.stocktwits.com/production/234409/thumb-1457903288.png', 'join_date': '2013-05-19', 'official': False, 'identity': 'User', 'classification': [], 'followers': 22857, 'following': 7325, 'ideas': 33406, 'watchlist_stocks_count': 9, 'like_count': 319}, 'source': {'id': 2269, 'title': 'StockTwits Web', 'url': 'https://stocktwits.com'}, 'symbols': [{'id': 679, 'symbol': 'SPX', 'title': 'S&P 500 Index', 'aliases': [], 'is_following': False, 'watchlist_count': 37218}, {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 279728}, {'id': 864, 'symbol': 'AMZN', 'title': 'Amazon.com Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 189951}, {'id': 1073, 'symbol': 'BIDU', 'title': 'Baidu, Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 30452}, {'id': 2839, 'symbol': 'NFLX', 'title': 'Netflix, Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 163261}, {'id': 2925, 'symbol': 'NVDA', 'title': 'NVIDIA Corporation', 'aliases': [], 'is_following': False, 'watchlist_count': 123239}, {'id': 3083, 'symbol': 'BKNG', 'title': 'Booking Holdings Inc', 'aliases': ['PCLN'], 'is_following': False, 'watchlist_count': 12769}, {'id': 4979, 'symbol': 'DIA', 'title': 'SPDR Dow Jones Industrial Average', 'aliases': [], 'is_following': False, 'watchlist_count': 9169}, {'id': 5930, 'symbol': 'IWM', 'title': 'iShares Russell 2000 Index ETF', 'aliases': [], 'is_following': False, 'watchlist_count': 12328}, {'id': 7271, 'symbol': 'SPY', 'title': 'SPDR S&P 500', 'aliases': [], 'is_following': False, 'watchlist_count': 111295}, {'id': 7871, 'symbol': 'FB', 'title': 'Facebook', 'aliases': ['FBOOK'], 'is_following': False, 'watchlist_count': 199565}, {'id': 8660, 'symbol': 'TSLA', 'title': 'Tesla, Inc.', 'aliases': [], 'is_following': False, 'watchlist_count': 196074}, {'id': 9581, 'symbol': 'QQQ', 'title': 'PowerShares Nasdaq-100 QQQ', 'aliases': ['QQQQ'], 'is_following': False, 'watchlist_count': 38037}, {'id': 9698, 'symbol': 'RUT', 'title': 'Russell 2000 Index', 'aliases': ['RUTX'], 'is_following': False, 'watchlist_count': 2407}, {'id': 11190, 'symbol': 'NDX', 'title': 'NASDAQ Composite', 'aliases': [], 'is_following': False, 'watchlist_count': 9835}, {'id': 11938, 'symbol': 'GOOGL', 'title': 'Alphabet Inc. Class A', 'aliases': [], 'is_following': False, 'watchlist_count': 58150}, {'id': 12100, 'symbol': 'BABA', 'title': 'Alibaba', 'aliases': ['ALIBABA'], 'is_following': False, 'watchlist_count': 130670}], 'links': [{'title': 'Market Maker Moves For W/E 1/25/2019', 'url': 'http://www.tradewithjoe.com/market-maker-moves-for-w-e-1-25-2019/', 'shortened_url': 'http://www.tradewithjoe.com/market-maker-moves-for-w-e-1-25-2019/', 'shortened_expanded_url': 'tradewithjoe.com/market-mak...', 'description': 'The expected move that a stock makes is very important to know. The easiest way to get an idea of the move is to price a straddle at the close of trading on Friday. That is buying one call and one put at an ATM strike.', 'image': 'http://www.tradewithjoe.com/wp-content/uploads/2018/07/tsla-1.png', 'created_at': '2019-01-22T14:14:36Z', 'video_url': None, 'source': {'name': 'Tradewithjoe', 'website': 'http://www.tradewithjoe.com'}}], 'mentioned_users': [], 'entities': {'sentiment': None}}

# %%
len(obj['messages'])
# Out:
# 30

# %%
obj['symbols']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-3814d32b9097> in <module>()
# ----> 1 obj['symbols']
#
# KeyError: 'symbols'

# %% [markdown]
# This list is what we want to store, so we convert the list to a json string and append that string to a file.

# %%
import requests
import time
import json

symbolList = ['SPX', 'DJIA', 'SPY', 'QQQ', 'AAPL', 'GOOG', 'FB', 'AMZN', 'JPM', 'WFC', 'BA', 'TWTR', 'BLK', 'DIA', 'MSFT', 'AMD', 'BRK.B', 'JNJ', 'XOM', 'BAC', 'CVX', 'PG', 'T', 'HD', 'PFE', 'UNH', 'V', 'VZ', 'C', 'INTC', 'CSCO', 'CMCSA', 'GOOGL', 'NVDA', 'AMGN', 'TXN', 'AVGO', 'DIS', 'GILD', 'QCOM', 'NFLX', 'PYPL', 'KHC', 'ADBE', 'PCLN', 'CHTR', 'SBUX', 'WMT', 'TGT', 'COST', 'CELG', 'WBA', 'MMM', 'AXP', 'CAT', 'GE', 'GS', 'IBM', 'MCD', 'MRK', 'NKE', 'TRV', 'ABBV', 'ABT', 'AIG', 'ALL', 'BIIB', 'BK', 'BMY', 'CL', 'COF', 'COP', 'CVS', 'DHR', 'DUK', 'DWDP', 'EMR', 'EXC', 'F', 'FDX', 'FOX', 'GD', 'GM', 'HAL', 'HON', 'KMI', 'KO', 'LLY', 'LMT', 'LOW', 'MA', 'MDLZ', 'MDT', 'MET', 'MO', 'MON', 'MS', 'NEE', 'ORCL', 'OXY', 'PEP', 'PM', 'RTN', 'SLB', 'SO', 'SPG', 'TWX', 'UNP', 'UPS', 'USB', 'UTX']
numSymbols = len(symbolList)

ctr=0
while ctr<10000:

    # make the request
    url="https://api.stocktwits.com/api/2/streams/symbol/"
    url=url+symbolList[ctr % numSymbols]+".json"
    r=requests.get(url)
    # check status of request
    status_code=r.status_code
    if status_code==200:

        # convert from json
        obj=r.json()
                        
        # convert the list to json
        txt=json.dumps(obj)
      
        # print it out
        fout=open('Twits.txt','a')
        fout.write(txt)
        fout.write("\r\n")
        fout.close()
    else:
        print("bad status code")

    # wait 30 seconds before making next request
    #
    time.sleep(30)
            
    # record ctr in status file
    fout2=open('status.txt','w')
    fout2.write(str(ctr))
    fout2.close()
    ctr=ctr+1
# Out:
# bad status code
# bad status code

# %% [markdown]
# Note that we write each list to a file as a json string. Each json string is a single line of the file.
#
# Retrieval of the data from the file works easily enough. We read in every string as a list.

# %%
with open("twitData2.txt","r") as fin:
    L=fin.readlines()
print(len(L))
L[1]

# %% [markdown]
# Then we convert from json strings to Python objects.

# %%
L[2]
# Out:
# '[{"id": 109439698, "body": "$SPY $DJIA $QQQ $IWM Remember when stocks went up down and sideways? Today&#39;s stocks go up, more up, and rocket ship up. Sounds about right!", "created_at": "2018-01-18T19:35:01Z", "user": {"id": 215444, "username": "Mr_Derivatives", "name": "Heisenberg", "avatar_url": "https://avatars.stocktwits.com/production/215444/thumb-1452826394.png", "avatar_url_ssl": "https://avatars.stocktwits.com/production/215444/thumb-1452826394.png", "join_date": "2013-02-17", "official": false, "identity": "User", "classification": ["suggested"], "followers": 14810, "following": 6, "ideas": 7184, "watchlist_stocks_count": 27, "like_count": 1975}, "source": {"id": 2269, "title": "StockTwits Web", "url": "https://stocktwits.com"}, "symbols": [{"id": 677, "symbol": "DJIA", "title": "Dow Jones Industrial Index", "is_following": false}, {"id": 5930, "symbol": "IWM", "title": "iShares Russell 2000 Index ETF", "is_following": false}, {"id": 7271, "symbol": "SPY", "title": "SPDR S&P 500", "is_following": false}, {"id": 9581, "symbol": "QQQ", "title": "PowerShares Nasdaq-100 QQQ", "is_following": false}], "conversation": {"parent_message_id": 109439698, "in_reply_to_message_id": null, "parent": true, "replies": 2}, "likes": {"total": 4, "user_ids": [306821, 938436, 2160, 109017]}, "mentioned_users": [], "entities": {"sentiment": null}}, {"id": 109438235, "body": "$SODA tanking $DJIA", "created_at": "2018-01-18T19:27:23Z", "user": {"id": 727867, "username": "dllshady", "name": "Adil Siddiq", "avatar_url": "http://avatars.stocktwits.com/images/default_avatar_thumb.jpg", "avatar_url_ssl": "https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg", "join_date": "2016-04-12", "official": false, "identity": "User", "classification": [], "followers": 99, "following": 161, "ideas": 2201, "watchlist_stocks_count": 168, "like_count": 1993}, "source": {"id": 2095, "title": "StockTwits For Android ", "url": "http://www.stocktwits.com/mobile"}, "symbols": [{"id": 677, "symbol": "DJIA", "title": "Dow Jones Industrial Index", "is_following": false}, {"id": 9356, "symbol": "SODA", "title": "SodaStream International Ltd.", "is_following": false}], "mentioned_users": [], "entities": {"sentiment": {"basic": "Bearish"}}}, {"id": 109437680, "body": "$GE BLOCK TRADE [14:24:33] @ $16.83 for 1,000,000 shares.  $DJIA $SPY", "created_at": "2018-01-18T19:24:34Z", "user": {"id": 339513, "username": "equityswing", "name": "EquitySwing", "avatar_url": "https://avatars.stocktwits.com/production/339513/thumb-1498006810.png", "avatar_url_ssl": "https://avatars.stocktwits.com/production/339513/thumb-1498006810.png", "join_date": "2014-04-04", "official": false, "identity": "User", "classification": [], "followers": 1749, "following": 1399, "ideas": 48074, "watchlist_stocks_count": 48, "like_count": 2292}, "source": {"id": 2985, "title": "Equity$wing", "url": "https://www.equityswing.com"}, "symbols": [{"id": 677, "symbol": "DJIA", "title": "Dow Jones Industrial Index", "is_following": false}, {"id": 5481, "symbol": "GE", "title": "General Electric Co.", "is_following": false}, {"id": 7271, "symbol": "SPY", "title": "SPDR S&P 500", "is_following": false}], "mentioned_users": [], "entities": {"sentiment": null}}, {"id": 109437317, "body": "Intraday support/resistance: $SPX 2792.6/2804.6 $DTX 1124/1133.4 $DJIA 25950/26150 Nasdaq 7276.2/7310.2 $RUT 1577.2/1586.8; $VIX 11.7/12.4", "created_at": "2018-01-18T19:22:46Z", "user": {"id": 113239, "username": "DrKris", "name": "Kris Andersen", "avatar_url": "https://avatars.stocktwits.com/production/113239/thumb-1330129854.png", "avatar_url_ssl": "https://avatars.stocktwits.com/production/113239/thumb-1330129854.png", "join_date": "2011-10-20", "official": false, "identity": "User", "classification": ["suggested"], "followers": 114, "following": 28, "ideas": 3054, "watchlist_stocks_count": 0, "like_count": 3}, "source": {"id": 2269, "title": "StockTwits Web", "url": "https://stocktwits.com"}, "symbols": [{"i ...

# %%
fin=open("twitData2.txt","r")
line=fin.readline()

# %%
json.loads(line)
# Out:
# [{'id': 109442811,
#   'body': '$AMD is up 22% YTD in a good agreement with this bullish forecast http://lnkd.in/e536EPq $NVDA $MU $INTC $SPY $SPX $DIA $IWM $QQQ $AAPL',
#   'created_at': '2018-01-18T19:51:44Z',
#   'user': {'id': 1185614,
#    'username': 'donbird',
#    'name': 'Don Bird',
#    'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#    'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#    'join_date': '2017-09-11',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 12,
#    'following': 62,
#    'ideas': 341,
#    'watchlist_stocks_count': 1,
#    'like_count': 6},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'is_following': False},
#    {'id': 2310,
#     'symbol': 'INTC',
#     'title': 'Intel Corporation',
#     'is_following': False},
#    {'id': 2925,
#     'symbol': 'NVDA',
#     'title': 'NVIDIA Corporation',
#     'is_following': False},
#    {'id': 4331,
#     'symbol': 'AMD',
#     'title': 'Advanced Micro Devices, Inc.',
#     'is_following': False},
#    {'id': 4979,
#     'symbol': 'DIA',
#     'title': 'SPDR Dow Jones Industrial Average',
#     'is_following': False},
#    {'id': 5930,
#     'symbol': 'IWM',
#     'title': 'iShares Russell 2000 Index ETF',
#     'is_following': False},
#    {'id': 6403,
#     'symbol': 'MU',
#     'title': 'Micron Technology Inc.',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109442811.png',
#     'large': 'https://charts.stocktwits.com/production/large_109442811.png',
#     'original': 'https://charts.stocktwits.com/production/original_109442811.png',
#     'url': 'https://charts.stocktwits.com/production/original_109442811.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109442274,
#   'body': '$AMD is up 22% YTD in a good agreement with this bullish forecast  s://lnkd.in/e536EPq $NVDA $MU $INTC $SPY $SPX $DIA $IWM $QQQ $AAPL',
#   'created_at': '2018-01-18T19:48:44Z',
#   'user': {'id': 1185614,
#    'username': 'donbird',
#    'name': 'Don Bird',
#    'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#    'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#    'join_date': '2017-09-11',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 12,
#    'following': 62,
#    'ideas': 340,
#    'watchlist_stocks_count': 1,
#    'like_count': 6},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'is_following': False},
#    {'id': 2310,
#     'symbol': 'INTC',
#     'title': 'Intel Corporation',
#     'is_following': False},
#    {'id': 2925,
#     'symbol': 'NVDA',
#     'title': 'NVIDIA Corporation',
#     'is_following': False},
#    {'id': 4331,
#     'symbol': 'AMD',
#     'title': 'Advanced Micro Devices, Inc.',
#     'is_following': False},
#    {'id': 4979,
#     'symbol': 'DIA',
#     'title': 'SPDR Dow Jones Industrial Average',
#     'is_following': False},
#    {'id': 5930,
#     'symbol': 'IWM',
#     'title': 'iShares Russell 2000 Index ETF',
#     'is_following': False},
#    {'id': 6403,
#     'symbol': 'MU',
#     'title': 'Micron Technology Inc.',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109442274.png',
#     'large': 'https://charts.stocktwits.com/production/large_109442274.png',
#     'original': 'https://charts.stocktwits.com/production/original_109442274.png',
#     'url': 'https://charts.stocktwits.com/production/original_109442274.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109440557,
#   'body': '$SPX $SPY $SPXU We will hold on to our short positions until the end of Friday but stop commenting here for sometime until we better clarity',
#   'created_at': '2018-01-18T19:39:49Z',
#   'user': {'id': 1233505,
#    'username': 'pattern_based_trading',
#    'name': 'Unlocking the Algorithm',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1233505/thumb-1508625861.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1233505/thumb-1508625861.png',
#    'join_date': '2017-10-19',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 219,
#    'following': 29,
#    'ideas': 668,
#    'watchlist_stocks_count': 0,
#    'like_count': 87},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7270,
#     'symbol': 'SPXU',
#     'title': 'ProShares UltraPro Short S&P500',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 3, 'user_ids': [1296842, 256701, 1088900]},
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109440361,
#   'body': '$ES_F Closed another one @807.25 from 800.75. Keeping only one for a higher blast $SPY $SPX',
#   'created_at': '2018-01-18T19:38:50Z',
#   'user': {'id': 1225648,
#    'username': 'The_Archer',
#    'name': 'Watch Your Gains Mate!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'join_date': '2017-10-13',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 69,
#    'following': 5,
#    'ideas': 1148,
#    'watchlist_stocks_count': 2,
#    'like_count': 355},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'mentioned_users': ['@807'],
#   'entities': {'sentiment': None}},
#  {'id': 109440044,
#   'body': '$ES_F Good! $SPY $SPX',
#   'created_at': '2018-01-18T19:37:10Z',
#   'user': {'id': 1225648,
#    'username': 'The_Archer',
#    'name': 'Watch Your Gains Mate!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'join_date': '2017-10-13',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 69,
#    'following': 5,
#    'ideas': 1151,
#    'watchlist_stocks_count': 2,
#    'like_count': 356},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 3, 'user_ids': [970851, 886577, 646599]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109440044.jpg',
#     'large': 'https://charts.stocktwits.com/production/large_109440044.jpg',
#     'original': 'https://charts.stocktwits.com/production/original_109440044.jpg',
#     'url': 'https://charts.stocktwits.com/production/original_109440044.jpg'},
#    'sentiment': None}},
#  {'id': 109439743,
#   'body': 'Stochastic and Relative Strength are both oversold on $KIM. Any thoughts? https://goo.gl/zIxSv1 $SPX',
#   'created_at': '2018-01-18T19:35:15Z',
#   'user': {'id': 642977,
#    'username': 'thestockmonitor',
#    'name': 'thestockmonitor',
#    'avatar_url': 'https://avatars.stocktwits.com/production/642977/thumb-1448888880.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/642977/thumb-1448888880.png',
#    'join_date': '2015-11-30',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 814,
#    'following': 126,
#    'ideas': 14077,
#    'watchlist_stocks_count': 8,
#    'like_count': 531},
#   'source': {'id': 2373,
#    'title': 'Stock Monitor',
#    'url': 'https://www.stockmonitor.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 6085,
#     'symbol': 'KIM',
#     'title': 'Kimco Realty Corporation',
#     'is_following': False}],
#   'links': [{'title': 'KIM Stock Price - Kimco Realty Corporation Quote Today With Chart',
#     'url': 'https://goo.gl/zIxSv1',
#     'shortened_url': 'https://goo.gl/zIxSv1',
#     'shortened_expanded_url': 'stockmonitor.com/quote/kim/...',
#     'description': 'View the latest KIM stock price today with excellent interactive chart, latest alerts for Kimco Realty Corporation, with indicator levels, dividend and earnings details. Add KIM stock price to your free portfolio.',
#     'image': None,
#     'created_at': '2018-01-18T19:35:18Z',
#     'video_url': None,
#     'source': {'name': 'Stockmonitor',
#      'website': 'https://www.stockmonitor.com'}}],
#   'likes': {'total': 1, 'user_ids': [1051390]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109439743.png',
#     'large': 'https://charts.stocktwits.com/production/large_109439743.png',
#     'original': 'https://charts.stocktwits.com/production/original_109439743.png',
#     'url': 'https://charts.stocktwits.com/production/original_109439743.png'},
#    'sentiment': None}},
#  {'id': 109439290,
#   'body': '$SPY $SPX  out, take  the sting out of the getting caught in morning bull trap.',
#   'created_at': '2018-01-18T19:32:46Z',
#   'user': {'id': 749215,
#    'username': 'roio',
#    'name': 'ROIO',
#    'avatar_url': 'https://avatars.stocktwits.com/production/749215/thumb-1465236219.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/749215/thumb-1465236219.png',
#    'join_date': '2016-05-10',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 10,
#    'following': 93,
#    'ideas': 1497,
#    'watchlist_stocks_count': 23,
#    'like_count': 809},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109439017,
#   'body': '$SPY $SPX $VIX VIX SMASH incoming..',
#   'created_at': '2018-01-18T19:31:11Z',
#   'user': {'id': 1372744,
#    'username': 'BarnabyBull',
#    'name': 'Barnaby Bull',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1372744/thumb-1516208184.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1372744/thumb-1516208184.png',
#    'join_date': '2018-01-17',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 0,
#    'following': 0,
#    'ideas': 146,
#    'watchlist_stocks_count': 3,
#    'like_count': 22},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 680,
#     'symbol': 'VIX',
#     'title': 'CBOE Volatility Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 1, 'user_ids': [762068]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109439017.jpg',
#     'large': 'https://charts.stocktwits.com/production/large_109439017.jpg',
#     'original': 'https://charts.stocktwits.com/production/original_109439017.jpg',
#     'url': 'https://charts.stocktwits.com/production/original_109439017.jpg'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109438826,
#   'body': '$SWK Momentum on the rise, and Parabolic SAR switched to up. Thoughts on $SWK? https://goo.gl/nZDcFF $SPX',
#   'created_at': '2018-01-18T19:30:18Z',
#   'user': {'id': 642977,
#    'username': 'thestockmonitor',
#    'name': 'thestockmonitor',
#    'avatar_url': 'https://avatars.stocktwits.com/production/642977/thumb-1448888880.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/642977/thumb-1448888880.png',
#    'join_date': '2015-11-30',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 814,
#    'following': 126,
#    'ideas': 14075,
#    'watchlist_stocks_count': 8,
#    'like_count': 531},
#   'source': {'id': 2373,
#    'title': 'Stock Monitor',
#    'url': 'https://www.stockmonitor.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7320,
#     'symbol': 'SWK',
#     'title': 'Stanley Black & Decker, Inc.',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109438826.png',
#     'large': 'https://charts.stocktwits.com/production/large_109438826.png',
#     'original': 'https://charts.stocktwits.com/production/original_109438826.png',
#     'url': 'https://charts.stocktwits.com/production/original_109438826.png'},
#    'sentiment': None}},
#  {'id': 109438664,
#   'body': '$SPY BLOCK TRADE [14:29:29] @ $279.6 for 1,955,450 shares.  $ES_F $SPX $SPXL $SPXS $SPXU $UPRO',
#   'created_at': '2018-01-18T19:29:30Z',
#   'user': {'id': 339513,
#    'username': 'equityswing',
#    'name': 'EquitySwing',
#    'avatar_url': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#    'join_date': '2014-04-04',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 1749,
#    'following': 1399,
#    'ideas': 48078,
#    'watchlist_stocks_count': 48,
#    'like_count': 2292},
#   'source': {'id': 2985,
#    'title': 'Equity$wing',
#    'url': 'https://www.equityswing.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7270,
#     'symbol': 'SPXU',
#     'title': 'ProShares UltraPro Short S&P500',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 7576,
#     'symbol': 'UPRO',
#     'title': 'ProShares UltraPro S&P500',
#     'is_following': False},
#    {'id': 11698,
#     'symbol': 'SPXL',
#     'title': 'Direxion Large Cap Bull 3X Shares',
#     'is_following': False},
#    {'id': 12053,
#     'symbol': 'SPXS',
#     'title': 'Direxion Daily S&P500 Bear 3X Shares',
#     'is_following': False}],
#   'reshares': {'reshared_count': 1, 'user_ids': [306821]},
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109438578,
#   'body': '$SPY BLOCK TRADE [14:29:4] @ $279.6 for 1,955,450 shares.  $ES_F $SPX $SPXL $SPXS $SPXU $UPRO',
#   'created_at': '2018-01-18T19:29:05Z',
#   'user': {'id': 339513,
#    'username': 'equityswing',
#    'name': 'EquitySwing',
#    'avatar_url': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#    'join_date': '2014-04-04',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 1749,
#    'following': 1399,
#    'ideas': 48075,
#    'watchlist_stocks_count': 48,
#    'like_count': 2292},
#   'source': {'id': 2985,
#    'title': 'Equity$wing',
#    'url': 'https://www.equityswing.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7270,
#     'symbol': 'SPXU',
#     'title': 'ProShares UltraPro Short S&P500',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 7576,
#     'symbol': 'UPRO',
#     'title': 'ProShares UltraPro S&P500',
#     'is_following': False},
#    {'id': 11698,
#     'symbol': 'SPXL',
#     'title': 'Direxion Large Cap Bull 3X Shares',
#     'is_following': False},
#    {'id': 12053,
#     'symbol': 'SPXS',
#     'title': 'Direxion Daily S&P500 Bear 3X Shares',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109438196,
#   'body': '$ES_F Still waiting for the real deal! $SPY $SPX',
#   'created_at': '2018-01-18T19:27:12Z',
#   'user': {'id': 1225648,
#    'username': 'The_Archer',
#    'name': 'Watch Your Gains Mate!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'join_date': '2017-10-13',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 69,
#    'following': 5,
#    'ideas': 1148,
#    'watchlist_stocks_count': 2,
#    'like_count': 355},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 2, 'user_ids': [886577, 1373118]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109438196.PNG',
#     'large': 'https://charts.stocktwits.com/production/large_109438196.PNG',
#     'original': 'https://charts.stocktwits.com/production/original_109438196.PNG',
#     'url': 'https://charts.stocktwits.com/production/original_109438196.PNG'},
#    'sentiment': None}},
#  {'id': 109438098,
#   'body': '$SPY $DIA $QQQ $SPX Starting to look like the market is actually melting up! This can bring a lot of short pain. Hopefully on $CVO',
#   'created_at': '2018-01-18T19:26:40Z',
#   'user': {'id': 511120,
#    'username': 'TankTopTrader',
#    'name': 'TankTopTrader',
#    'avatar_url': 'https://avatars.stocktwits.com/production/511120/thumb-1503406817.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/511120/thumb-1503406817.png',
#    'join_date': '2015-05-01',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 76,
#    'following': 79,
#    'ideas': 3676,
#    'watchlist_stocks_count': 38,
#    'like_count': 151},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 4872,
#     'symbol': 'CVO',
#     'title': 'Cenveo Inc.',
#     'is_following': False},
#    {'id': 4979,
#     'symbol': 'DIA',
#     'title': 'SPDR Dow Jones Industrial Average',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False}],
#   'likes': {'total': 1, 'user_ids': [710938]},
#   'mentioned_users': [],
#   'entities': {'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109437624,
#   'body': '$SPY $SPX Bullish &quot;DOVE WING&quot; Pattern.  Set to GO HIGHER',
#   'created_at': '2018-01-18T19:24:19Z',
#   'user': {'id': 1372744,
#    'username': 'BarnabyBull',
#    'name': 'Barnaby Bull',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1372744/thumb-1516208184.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1372744/thumb-1516208184.png',
#    'join_date': '2018-01-17',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 0,
#    'following': 0,
#    'ideas': 141,
#    'watchlist_stocks_count': 3,
#    'like_count': 22},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109437624.png',
#     'large': 'https://charts.stocktwits.com/production/large_109437624.png',
#     'original': 'https://charts.stocktwits.com/production/original_109437624.png',
#     'url': 'https://charts.stocktwits.com/production/original_109437624.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109437555,
#   'body': '$SPX $SPY $AAPL $QQQ \n\nBUY HERE MARKETS REVERSING',
#   'created_at': '2018-01-18T19:23:55Z',
#   'user': {'id': 1347101,
#    'username': 'JacksinvCapital',
#    'name': 'JacksinvCapital',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1347101/thumb-1515380783.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1347101/thumb-1515380783.png',
#    'join_date': '2018-01-03',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 29,
#    'following': 2,
#    'ideas': 933,
#    'watchlist_stocks_count': 6,
#    'like_count': 6},
#   'source': {'id': 1149,
#    'title': 'StockTwits for iOS',
#    'url': 'http://www.stocktwits.com/mobile'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False}],
#   'likes': {'total': 1, 'user_ids': [1329471]},
#   'mentioned_users': [],
#   'entities': {'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109437317,
#   'body': 'Intraday support/resistance: $SPX 2792.6/2804.6 $DTX 1124/1133.4 $DJIA 25950/26150 Nasdaq 7276.2/7310.2 $RUT 1577.2/1586.8; $VIX 11.7/12.4',
#   'created_at': '2018-01-18T19:22:46Z',
#   'user': {'id': 113239,
#    'username': 'DrKris',
#    'name': 'Kris Andersen',
#    'avatar_url': 'https://avatars.stocktwits.com/production/113239/thumb-1330129854.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/113239/thumb-1330129854.png',
#    'join_date': '2011-10-20',
#    'official': False,
#    'identity': 'User',
#    'classification': ['suggested'],
#    'followers': 114,
#    'following': 28,
#    'ideas': 3054,
#    'watchlist_stocks_count': 0,
#    'like_count': 3},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 677,
#     'symbol': 'DJIA',
#     'title': 'Dow Jones Industrial Index',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 680,
#     'symbol': 'VIX',
#     'title': 'CBOE Volatility Index',
#     'is_following': False},
#    {'id': 9698,
#     'symbol': 'RUT',
#     'title': 'Russell 2000 Index',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109437301,
#   'body': '$ES_F $SPY $SPX Very well',
#   'created_at': '2018-01-18T19:22:42Z',
#   'user': {'id': 41414,
#    'username': 'vrm',
#    'name': 'vic',
#    'avatar_url': 'https://avatars.stocktwits.com/production/41414/thumb-1447456999.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/41414/thumb-1447456999.png',
#    'join_date': '2011-01-08',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 87,
#    'following': 73,
#    'ideas': 2338,
#    'watchlist_stocks_count': 97,
#    'like_count': 257},
#   'source': {'id': 1149,
#    'title': 'StockTwits for iOS',
#    'url': 'http://www.stocktwits.com/mobile'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'reshare_message': {'reshared_count': 1,
#    'reshared_deleted': False,
#    'reshared_user_deleted': False,
#    'parent_reshared_deleted': False,
#    'message': {'id': 109431890,
#     'body': '$ES_F today, the leader NASDAQ is green. If it stays in green, I expect $SPY $SPX will be Green too',
#     'created_at': '2018-01-18T18:53:59Z',
#     'user': {'id': 41414,
#      'username': 'vrm',
#      'name': 'vic',
#      'avatar_url': 'https://avatars.stocktwits.com/production/41414/thumb-1447456999.png',
#      'avatar_url_ssl': 'https://avatars.stocktwits.com/production/41414/thumb-1447456999.png',
#      'join_date': '2011-01-08',
#      'official': False,
#      'identity': 'User',
#      'classification': [],
#      'followers': 87,
#      'following': 73,
#      'ideas': 2338,
#      'watchlist_stocks_count': 97,
#      'like_count': 257},
#     'source': {'id': 1149,
#      'title': 'StockTwits for iOS',
#      'url': 'http://www.stocktwits.com/mobile'},
#     'symbols': [{'id': 647,
#       'symbol': 'ES_F',
#       'title': 'E-Mini S&P 500 Futures',
#       'is_following': False},
#      {'id': 679,
#       'symbol': 'SPX',
#       'title': 'S&P 500 Index',
#       'is_following': False},
#      {'id': 7271,
#       'symbol': 'SPY',
#       'title': 'SPDR S&P 500',
#       'is_following': False}],
#     'mentioned_users': [],
#     'entities': {'sentiment': None}}},
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109437284,
#   'body': '$QQQ $SPXU $SPX $SPY  orly?',
#   'created_at': '2018-01-18T19:22:38Z',
#   'user': {'id': 975256,
#    'username': 'SOUPorDAD',
#    'name': 'SOUPorDAD',
#    'avatar_url': 'https://avatars.stocktwits.com/production/975256/thumb-1489003456.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/975256/thumb-1489003456.png',
#    'join_date': '2017-02-28',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 6,
#    'following': 85,
#    'ideas': 159,
#    'watchlist_stocks_count': 6,
#    'like_count': 141},
#   'source': {'id': 2095,
#    'title': 'StockTwits For Android ',
#    'url': 'http://www.stocktwits.com/mobile'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7270,
#     'symbol': 'SPXU',
#     'title': 'ProShares UltraPro Short S&P500',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False}],
#   'conversation': {'parent_message_id': 109437284,
#    'in_reply_to_message_id': None,
#    'parent': True,
#    'replies': 1},
#   'likes': {'total': 1, 'user_ids': [679519]},
#   'reshare_message': {'reshared_count': 1,
#    'reshared_deleted': False,
#    'reshared_user_deleted': False,
#    'parent_reshared_deleted': False,
#    'message': {'id': 109149294,
#     'body': '$SPX $SPY $SPXU $QQQ This pull back to continue through out the week Our analysis &amp; next strategy will be shared @ http://pattern-based-trading.com',
#     'created_at': '2018-01-17T00:21:36Z',
#     'user': {'id': 1233505,
#      'username': 'pattern_based_trading',
#      'name': 'Unlocking the Algorithm',
#      'avatar_url': 'https://avatars.stocktwits.com/production/1233505/thumb-1508625861.png',
#      'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1233505/thumb-1508625861.png',
#      'join_date': '2017-10-19',
#      'official': False,
#      'identity': 'User',
#      'classification': [],
#      'followers': 219,
#      'following': 29,
#      'ideas': 667,
#      'watchlist_stocks_count': 0,
#      'like_count': 87},
#     'source': {'id': 2269,
#      'title': 'StockTwits Web',
#      'url': 'https://stocktwits.com'},
#     'symbols': [{'id': 679,
#       'symbol': 'SPX',
#       'title': 'S&P 500 Index',
#       'is_following': False},
#      {'id': 7270,
#       'symbol': 'SPXU',
#       'title': 'ProShares UltraPro Short S&P500',
#       'is_following': False},
#      {'id': 7271,
#       'symbol': 'SPY',
#       'title': 'SPDR S&P 500',
#       'is_following': False},
#      {'id': 9581,
#       'symbol': 'QQQ',
#       'title': 'PowerShares Nasdaq-100 QQQ',
#       'is_following': False}],
#     'links': [{'title': 'Pattern Based Hypothesis Trading',
#       'url': 'http://pattern-based-trading.com',
#       'shortened_url': 'http://pattern-based-trading.com',
#       'shortened_expanded_url': 'pattern-based-trading.com/',
#       'description': 'We will try to look from the positive side today. Thanks to our MU, FIT, LRCX, UEPS, HUN, FANG positions, our portfolio closed the day with +0.88% gain despite we had a bad entry in our directional SPY trade by initiating SPXU with 10% weight this morning.',
#       'image': 'http://pattern-based-trading.com/wp-content/uploads/2018/01/SPY-1-3-18.jpg',
#       'created_at': '2018-01-17T00:21:36Z',
#       'video_url': None,
#       'source': {'name': 'Pattern-based-trading',
#        'website': 'http://pattern-based-trading.com'}}],
#     'likes': {'total': 1, 'user_ids': [364426]},
#     'mentioned_users': [],
#     'entities': {'sentiment': {'basic': 'Bearish'}}}},
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109437118,
#   'body': 'Watch if $VIX closes within Bollinger bands  then high probability market will grind higher into option exp. $SPY $SPX',
#   'created_at': '2018-01-18T19:21:44Z',
#   'user': {'id': 505674,
#    'username': 'Keez',
#    'name': 'Mark Keyworth',
#    'avatar_url': 'https://avatars.stocktwits.com/production/505674/thumb-1454699261.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/505674/thumb-1454699261.png',
#    'join_date': '2015-04-22',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 23,
#    'following': 67,
#    'ideas': 228,
#    'watchlist_stocks_count': 10,
#    'like_count': 72},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 680,
#     'symbol': 'VIX',
#     'title': 'CBOE Volatility Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 1, 'user_ids': [1011890]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109437118.jpg',
#     'large': 'https://charts.stocktwits.com/production/large_109437118.jpg',
#     'original': 'https://charts.stocktwits.com/production/original_109437118.jpg',
#     'url': 'https://charts.stocktwits.com/production/original_109437118.jpg'},
#    'sentiment': None}},
#  {'id': 109436702,
#   'body': '$SVXY $ADI $AMD $AVGO $XLNX $AMAT $AAPL $CRM $EA $WYN $WYNN Among todays leaders on $SPX $SPY $JPM $PYPL',
#   'created_at': '2018-01-18T19:19:28Z',
#   'user': {'id': 980786,
#    'username': 'ACTIONABLE_IDEAS',
#    'name': 'ACTIONABLE_IDEAS',
#    'avatar_url': 'https://avatars.stocktwits.com/production/980786/thumb-1501541160.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/980786/thumb-1501541160.png',
#    'join_date': '2017-03-03',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 559,
#    'following': 0,
#    'ideas': 4592,
#    'watchlist_stocks_count': 3,
#    'like_count': 0},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 686, 'symbol': 'AAPL', 'title': 'Apple Inc.', 'is_following': False},
#    {'id': 827,
#     'symbol': 'AMAT',
#     'title': 'Applied Materials Inc.',
#     'is_following': False},
#    {'id': 1766,
#     'symbol': 'EA',
#     'title': 'Electronic Arts Inc.',
#     'is_following': False},
#    {'id': 4152,
#     'symbol': 'WYNN',
#     'title': 'Wynn Resorts Ltd.',
#     'is_following': False},
#    {'id': 4161,
#     'symbol': 'XLNX',
#     'title': 'Xilinx Inc.',
#     'is_following': False},
#    {'id': 4239,
#     'symbol': 'ADI',
#     'title': 'Analog Devices Inc.',
#     'is_following': False},
#    {'id': 4331,
#     'symbol': 'AMD',
#     'title': 'Advanced Micro Devices, Inc.',
#     'is_following': False},
#    {'id': 4828,
#     'symbol': 'CRM',
#     'title': 'Salesforce.com',
#     'is_following': False},
#    {'id': 6020,
#     'symbol': 'JPM',
#     'title': 'JPMorgan Chase & Co.',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 7788,
#     'symbol': 'WYN',
#     'title': 'Wyndham Worldwide Corporation',
#     'is_following': False},
#    {'id': 7901, 'symbol': 'AVGO', 'title': 'Broadcom', 'is_following': False},
#    {'id': 11253,
#     'symbol': 'SVXY',
#     'title': 'Short VIX Short-Term Futures ETF',
#     'is_following': False},
#    {'id': 12608, 'symbol': 'PYPL', 'title': 'PayPal', 'is_following': False}],
#   'likes': {'total': 1, 'user_ids': [1329471]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109436702.png',
#     'large': 'https://charts.stocktwits.com/production/large_109436702.png',
#     'original': 'https://charts.stocktwits.com/production/original_109436702.png',
#     'url': 'https://charts.stocktwits.com/production/original_109436702.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109436617,
#   'body': '$ES_F And here it is the spectacular save + accumulation phase. 800.75 trail stop for longs that want to hold for 2816-20 $SPY $SPX',
#   'created_at': '2018-01-18T19:19:02Z',
#   'user': {'id': 1225648,
#    'username': 'The_Archer',
#    'name': 'Watch Your Gains Mate!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'join_date': '2017-10-13',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 69,
#    'following': 5,
#    'ideas': 1145,
#    'watchlist_stocks_count': 2,
#    'like_count': 354},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 3, 'user_ids': [1172164, 982300, 886577]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109436617.PNG',
#     'large': 'https://charts.stocktwits.com/production/large_109436617.PNG',
#     'original': 'https://charts.stocktwits.com/production/original_109436617.PNG',
#     'url': 'https://charts.stocktwits.com/production/original_109436617.PNG'},
#    'sentiment': None}},
#  {'id': 109436530,
#   'body': '$ES_F $SPY $SPX Moving stop on 2795 runner to 2800 even. Trailing 5 points from here. Let&#39;s see how far we can get this to drag me along....',
#   'created_at': '2018-01-18T19:18:32Z',
#   'user': {'id': 1172164,
#    'username': 'DTWCoachandDude',
#    'name': 'Watch our traders trade LIVE!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1172164/thumb-1504025737.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1172164/thumb-1504025737.png',
#    'join_date': '2017-08-29',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 123,
#    'following': 12,
#    'ideas': 1006,
#    'watchlist_stocks_count': 10,
#    'like_count': 515},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'conversation': {'parent_message_id': 109436530,
#    'in_reply_to_message_id': None,
#    'parent': True,
#    'replies': 1},
#   'likes': {'total': 1, 'user_ids': [886577]},
#   'mentioned_users': [],
#   'entities': {'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109436472,
#   'body': '$SPY $SPX $DJIA $DIA $QQQ $COMPQ $TVIX $UVXY  \nDips = gifts',
#   'created_at': '2018-01-18T19:18:13Z',
#   'user': {'id': 368937,
#    'username': 'littlenickysmith',
#    'name': 'nick smith',
#    'avatar_url': 'https://avatars.stocktwits.com/production/368937/thumb-1426863256.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/368937/thumb-1426863256.png',
#    'join_date': '2014-06-26',
#    'official': False,
#    'identity': 'User',
#    'classification': ['suggested'],
#    'followers': 20405,
#    'following': 116,
#    'ideas': 38596,
#    'watchlist_stocks_count': 52,
#    'like_count': 1945},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 676,
#     'symbol': 'COMPQ',
#     'title': 'NASDAQ Composite Index',
#     'is_following': False},
#    {'id': 677,
#     'symbol': 'DJIA',
#     'title': 'Dow Jones Industrial Index',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 4979,
#     'symbol': 'DIA',
#     'title': 'SPDR Dow Jones Industrial Average',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9466,
#     'symbol': 'TVIX',
#     'title': 'VelocityShares Daily 2x VIX ST ETN',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False},
#    {'id': 11188,
#     'symbol': 'UVXY',
#     'title': 'ProShares Trust Ultra VIX Short-Term Futures ETF',
#     'is_following': False}],
#   'likes': {'total': 1, 'user_ids': [784861]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109436472.png',
#     'large': 'https://charts.stocktwits.com/production/large_109436472.png',
#     'original': 'https://charts.stocktwits.com/production/original_109436472.png',
#     'url': 'https://charts.stocktwits.com/production/original_109436472.png'},
#    'sentiment': None}},
#  {'id': 109436441,
#   'body': 'I got a buy signal for $SPX at 2:00pm. I would be looking for a pullback for a buying opportunity.',
#   'created_at': '2018-01-18T19:18:05Z',
#   'user': {'id': 1372729,
#    'username': 'SKalayjian',
#    'name': 'Stephen Kalayjian',
#    'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#    'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#    'join_date': '2018-01-17',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 0,
#    'following': 0,
#    'ideas': 11,
#    'watchlist_stocks_count': 0,
#    'like_count': 0},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'sentiment': None}},
#  {'id': 109436129,
#   'body': '$SOX $NDX Leading $SPX today $SPY $QQQ $SmH VIX red',
#   'created_at': '2018-01-18T19:16:29Z',
#   'user': {'id': 980786,
#    'username': 'ACTIONABLE_IDEAS',
#    'name': 'ACTIONABLE_IDEAS',
#    'avatar_url': 'https://avatars.stocktwits.com/production/980786/thumb-1501541160.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/980786/thumb-1501541160.png',
#    'join_date': '2017-03-03',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 558,
#    'following': 0,
#    'ideas': 4582,
#    'watchlist_stocks_count': 3,
#    'like_count': 0},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 526,
#     'symbol': 'SMH',
#     'title': 'VanEck Vectors Semiconductor ETF',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 9200,
#     'symbol': 'SOX',
#     'title': 'Philadelphia Semiconductor Index',
#     'is_following': False},
#    {'id': 9581,
#     'symbol': 'QQQ',
#     'title': 'PowerShares Nasdaq-100 QQQ',
#     'is_following': False},
#    {'id': 11190,
#     'symbol': 'NDX',
#     'title': 'NASDAQ Composite',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109436129.png',
#     'large': 'https://charts.stocktwits.com/production/large_109436129.png',
#     'original': 'https://charts.stocktwits.com/production/original_109436129.png',
#     'url': 'https://charts.stocktwits.com/production/original_109436129.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109435830,
#   'body': '$SPY $SPX RIPE Bull Flag ready for BREAKOUT HIGHER!',
#   'created_at': '2018-01-18T19:14:48Z',
#   'user': {'id': 1372744,
#    'username': 'BarnabyBull',
#    'name': 'Barnaby Bull',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1372744/thumb-1516208184.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1372744/thumb-1516208184.png',
#    'join_date': '2018-01-17',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 0,
#    'following': 0,
#    'ideas': 136,
#    'watchlist_stocks_count': 3,
#    'like_count': 20},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109435830.png',
#     'large': 'https://charts.stocktwits.com/production/large_109435830.png',
#     'original': 'https://charts.stocktwits.com/production/original_109435830.png',
#     'url': 'https://charts.stocktwits.com/production/original_109435830.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109435806,
#   'body': '$ES_F Where are momentum/breakout guys?? Come on. $SPY $SPX',
#   'created_at': '2018-01-18T19:14:41Z',
#   'user': {'id': 1225648,
#    'username': 'The_Archer',
#    'name': 'Watch Your Gains Mate!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1225648/thumb-1514198997.png',
#    'join_date': '2017-10-13',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 69,
#    'following': 5,
#    'ideas': 1142,
#    'watchlist_stocks_count': 2,
#    'like_count': 354},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109435806.PNG',
#     'large': 'https://charts.stocktwits.com/production/large_109435806.PNG',
#     'original': 'https://charts.stocktwits.com/production/original_109435806.PNG',
#     'url': 'https://charts.stocktwits.com/production/original_109435806.PNG'},
#    'sentiment': None}},
#  {'id': 109435486,
#   'body': '$SPX $SPY 229 advancing low was 129 $SVXY For cash flow',
#   'created_at': '2018-01-18T19:12:58Z',
#   'user': {'id': 980786,
#    'username': 'ACTIONABLE_IDEAS',
#    'name': 'ACTIONABLE_IDEAS',
#    'avatar_url': 'https://avatars.stocktwits.com/production/980786/thumb-1501541160.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/980786/thumb-1501541160.png',
#    'join_date': '2017-03-03',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 558,
#    'following': 0,
#    'ideas': 4580,
#    'watchlist_stocks_count': 3,
#    'like_count': 0},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False},
#    {'id': 11253,
#     'symbol': 'SVXY',
#     'title': 'Short VIX Short-Term Futures ETF',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109435486.png',
#     'large': 'https://charts.stocktwits.com/production/large_109435486.png',
#     'original': 'https://charts.stocktwits.com/production/original_109435486.png',
#     'url': 'https://charts.stocktwits.com/production/original_109435486.png'},
#    'sentiment': {'basic': 'Bullish'}}},
#  {'id': 109435360,
#   'body': 'Is that a Cup &amp; Handle I see (don&#39;t be jealous of my amazing artistry... I&#39;m gifted) in the $ES_F ?  $SPY $SPX',
#   'created_at': '2018-01-18T19:12:20Z',
#   'user': {'id': 1172164,
#    'username': 'DTWCoachandDude',
#    'name': 'Watch our traders trade LIVE!',
#    'avatar_url': 'https://avatars.stocktwits.com/production/1172164/thumb-1504025737.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1172164/thumb-1504025737.png',
#    'join_date': '2017-08-29',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 123,
#    'following': 12,
#    'ideas': 1006,
#    'watchlist_stocks_count': 10,
#    'like_count': 515},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 647,
#     'symbol': 'ES_F',
#     'title': 'E-Mini S&P 500 Futures',
#     'is_following': False},
#    {'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False},
#    {'id': 7271,
#     'symbol': 'SPY',
#     'title': 'SPDR S&P 500',
#     'is_following': False}],
#   'likes': {'total': 2, 'user_ids': [1225648, 886577]},
#   'mentioned_users': [],
#   'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_109435360.JPG',
#     'large': 'https://charts.stocktwits.com/production/large_109435360.JPG',
#     'original': 'https://charts.stocktwits.com/production/original_109435360.JPG',
#     'url': 'https://charts.stocktwits.com/production/original_109435360.JPG'},
#    'sentiment': None}},
#  {'id': 109435217,
#   'body': '$SPX I love this stock market, but just got an alert that the &quot;Doom Index&quot; is flashing an &quot;extreme warning&quot;? WTH?',
#   'created_at': '2018-01-18T19:11:33Z',
#   'user': {'id': 817029,
#    'username': 'SkiesOfBlue',
#    'name': 'Hey Neal',
#    'avatar_url': 'https://avatars.stocktwits.com/production/817029/thumb-1493049865.png',
#    'avatar_url_ssl': 'https://avatars.stocktwits.com/production/817029/thumb-1493049865.png',
#    'join_date': '2016-08-10',
#    'official': False,
#    'identity': 'User',
#    'classification': [],
#    'followers': 280,
#    'following': 26,
#    'ideas': 8713,
#    'watchlist_stocks_count': 70,
#    'like_count': 2872},
#   'source': {'id': 2269,
#    'title': 'StockTwits Web',
#    'url': 'https://stocktwits.com'},
#   'symbols': [{'id': 679,
#     'symbol': 'SPX',
#     'title': 'S&P 500 Index',
#     'is_following': False}],
#   'mentioned_users': [],
#   'entities': {'sentiment': None}}]
